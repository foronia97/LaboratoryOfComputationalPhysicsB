# %% [markdown]
# # Exercise 3: Convolutional Neural Networks
#
# Gruppo Stocafisici: Edoardo Antonaci, Angelica Foroni, Francesco Mazza, Leonardo Salicari.
#
# 1. Experiment with different architectures (which was left as an open point when “NCONV”
# variable was introduced), in particular try at least another version where only one
# convolutional layer is introduced instead of two, and where any number of dense layers may
# be used, with the global constraint of using a network with at most 600 trainable parameters.
# The filter length in the second convolutional layer may be shorter.
# Is the number of parameters scaling more quickly by adding Dense layers or Conv1D
# layers?
# Check which configuration works better by comparing the performances quantitatively.
# 2. Visualize the “confusion matrix” (look for similar examples in the material available or by
# googling)
# 3. With two convolutional layers, plot also the weights of the second layer and try to see if
# regularization may improve the performances by varying the parameter lambda of the L1 or
# of the L2 regularization; see lambda in eqs.(43) and (52) in the review. There is also a mixed
# version (l1_l2?) that can be tried. Is any value of lambda good? Is there any intermediate
# value where the performances of the network are better? Is there any improvement in the
# visualization and understanding of the weights in the filters? Note that the regularization we
# introduced acts on the w’s, not on the biases. One can also try the equivalent procedure for
# biases or for the output of the relu units (see Keras doc.), if there is any reason for
# suspecting that it may help. In our case, the logic was to let the weights of the filters go to
# zero if not needed, hence that kind of regularization was selected.
# 4. By reducing the signal-to-noise ratio, namely the amplitude of the external signal in the data
# (A) with respect to the step typical size of the jump process, check where the network starts
# to fail discriminating the categories.

# %% [markdown]
# ### Loading dataset
# We are going to use the dataset generated during the lecture

# %%
import subprocess,csv
import random
import math
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

name = '_ts_L60_Z12_A12_DX50_bias5_N10000.csv'
xname = 'DATA/x' + name
yname = 'DATA/y' + name

# Dataset
x = np.loadtxt(xname, delimiter=',', dtype=float)
N = x.shape[0]
L = x.shape[1]

# Labels
categ = np.loadtxt(yname, delimiter=',', dtype=int)
n_class = 3
y = np.zeros((N, n_class ))
for i in range(N):
    y[i][categ[i]] = 1.

# Removing avg and scaling data
x_avg = np.mean(x, axis=1).reshape(N,1) # average over sample (i.e. over rows)
x = (x - x_avg)/100 # one line to remove avg and scale; faster than a for loop
    
# Training and Validation
# Note, these are view, not copies
train_frac = .8
N_train = int(N*train_frac)
x_train = x[0:N_train,:]
y_train = y[0:N_train,:]
x_val = x[N_train:,:]
y_val = y[N_train:,:]

# Plotting some data
for k in range(3):
    plt.plot(x_train[k])
    
# Reshape for Keras
# Hence adding an extra dim wich correspond to the depth 
x_train = x_train.reshape(x_train.shape[0],L,1)
x_val = x_val.reshape(x_val.shape[0],L,1)

input_size = (L,1)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

name = '_ts_L60_Z12_A12_DX50_bias5_N10000.csv'
xname = fname
yname = 'y' + name

# Dataset
x = np.loadtxt(xname, delimiter=',', dtype=float)
N = x.shape[0]
L = x.shape[1]

# Labels
categ = np.loadtxt(yname, delimiter=',', dtype=int)
n_class = 3
y = np.zeros((N, n_class ))
for i in range(N):
    y[i][categ[i]] = 1.

# Removing avg and scaling data
x_avg = np.mean(x, axis=1).reshape(N,1) # average over sample (i.e. over rows)
x = (x - x_avg)/100 # one line to remove avg and scale; faster than a for loop
    
# Training and Validation
# Note, these are view, not copies
train_frac = .8
N_train = int(N*train_frac)
x_train = x[0:N_train,:]
y_train = y[0:N_train,:]
x_val = x[N_train:,:]
y_val = y[N_train:,:]

# Plotting some data
for k in range(3):
    plt.plot(x_train[k])
    
# Reshape for Keras
# Hence adding an extra dim wich correspond to the depth 
x_train = x_train.reshape(x_train.shape[0],L,1)
x_val = x_val.reshape(x_val.shape[0],L,1)

input_size = (L,1)

# %% [markdown]
# ## 1: CNN with different topologies

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.utils.layer_utils import count_params # for count number of parameters
from keras.losses import categorical_crossentropy
from keras import initializers, regularizers
from keras import optimizers

def create_model(NCONV=1, n_dense_layers=1, kernel_size_diff=1, summary=False):
    ''' 
    Creates a CNN with different topologies by changing NCONV 
    Returns the model and the number of trainable parameters
    
    n_dense_layers = number of dense layers in the CNN
    kernel_size_diff = (kernel_size first Conv layer) - (kernel_size second Conv layer)
    summary = print model.summary()
    
    NCONV == 1:
        From baiesi lecture
        Conv -> AvgPadding -> Conv -> Fattern -> Dense*(n_dense_layers) -> Dense (output)
    NCONV == 2: 
        Only one Conv layer
        Conv -> AvgPadding -> Fattern -> Dense*(n_dense_layers) -> Dense (output)
        
    '''
    if n_dense_layers < 1:
        raise('n_dense_layer must be int and >= 1')
        
    # Defining regulirizer
    reg = regularizers.l1(0.1)
    # Used to initialize kernel 
    init = initializers.RandomNormal(mean = 0,
                                   stddev = .05)
    model = Sequential()

    if NCONV == 1:
        model.add( Conv1D(filters=5,
                          kernel_size = 11,                              
                          kernel_initializer = init,
                          kernel_regularizer = reg,
                          activation = 'relu',
                          input_shape = input_size
                         ) )
        model.add( AveragePooling1D(5) ) # max pooling windows' size
        model.add( Conv1D(filters=5, 
                          kernel_size = 11 - kernel_size_diff, 
                          activation = 'relu',) )
        model.add( Flatten() )
        for _ in range(n_dense_layers): # variable number of layers
            model.add( Dense(10, activation='relu') )
        model.add( Dropout(0.2) )
        
    elif NCONV == 2:
        model.add( Conv1D(filters=5,
                          kernel_size = 11,                              
                          kernel_initializer = init,
                          kernel_regularizer = reg,
                          activation = 'relu',
                          input_shape = input_size
                         ) )
        model.add( AveragePooling1D(5) ) # max pooling windows' size
        model.add( Flatten() )
        for _ in range(n_dense_layers): # variable number of layers
            model.add( Dense(10, activation='relu') )
        model.add( Dropout(0.2) )
    else:
        raise('NCONV must be an int: 1 or 2')
        
    # Output layer
    model.add(Dense(n_class, activation='softmax')) 
    
    # print model's details
    if summary: print(model.summary())
    # Number of trainable parameters
    trainable_count = count_params(model.trainable_weights)
    
    # Compiling model
    opt = optimizers.Nadam()
    model.compile( loss = categorical_crossentropy,
              optimizer = opt,
              metrics = ['accuracy'])
    
    return (model, trainable_count)

# %% [markdown]
# ### Training and test performance
#
#  Is the number of parameters scaling more quickly by adding Dense layers or Conv1D layers?

# %%
# Define dicts to test different topologies
# t1 == test 1
t1 = dict(NCONV = 1, n_dense_layers = 1, kernel_size_diff = 1)
t2 = dict(NCONV = 1, n_dense_layers = 2, kernel_size_diff = 1)
t3 = dict(NCONV = 1, n_dense_layers = 3, kernel_size_diff = 1)
t4 = dict(NCONV = 2, n_dense_layers = 1, kernel_size_diff = 1)
t5 = dict(NCONV = 2, n_dense_layers = 2, kernel_size_diff = 1)
t6 = dict(NCONV = 1, n_dense_layers = 1, kernel_size_diff = 4)

# Array with tests
tests = [t1,t2,t3,t4,t5,t6]
# Array with names for plotting porpuses
tests_plot = ['t1','t2','t3','t4','t5','t6']
# Array to save # of parameters
params = [0] * len(tests)

for idx,t in enumerate(tests):
    _, params[idx] = create_model(**t, summary=False) # **t is the syntax to 'unpack' values from dict
    
# Visualising number of parameters
plt.close()
plt.plot(tests_plot, params, '*')
plt.axhline(y=600, color='red') # line of 600 parameters
plt.xlabel('Tests')
plt.ylabel('# of trainable parameters')
# Out:
# Text(0, 0.5, '# of trainable parameters')

# %% [markdown]
# #### Comment
# It's seems like that removing a `Conv1D` layer the number of trainable parameters grows. Looking at the summary of the models, this apparent contradiction seems to be solve by the fact that in the case of 2 convolutional layers the `output size` of the layer's output is smaller compared to the model with only one convolutional layer.
#
# Than, the fully connected layers (the `Dense` one) han a number of trainable parameters related to the number of weights and biases which grows quickly with the `output size` of the previous layer. Hence, the one-convolutional-layer model has more parameters due to its bigger output given to the fully connected layer.
#
# For more info, use the option `summary=True` in the `create_model()` function's call.
#
# ### Performance comparison
# It'll be trained models relative to configurations `t2`, `t4` and `t6`

# %%
model2, _ = create_model(**t2)
model4, _ = create_model(**t4)
model6, _ = create_model(**t6)

# Training
batch_size = 250
epochs = 100

fit2 = model2.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
fit4 = model4.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
fit6 = model6.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 1s - loss: 1.2136 - accuracy: 0.3355 - val_loss: 1.1364 - val_accuracy: 0.3710
# Epoch 2/100
#  - 0s - loss: 1.1162 - accuracy: 0.3591 - val_loss: 1.1053 - val_accuracy: 0.3690
# Epoch 3/100
#  - 0s - loss: 1.1031 - accuracy: 0.3549 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 4/100
#  - 0s - loss: 1.1020 - accuracy: 0.3370 - val_loss: 1.1021 - val_accuracy: 0.3335
# Epoch 5/100
#  - 0s - loss: 1.1019 - accuracy: 0.3347 - val_loss: 1.1027 - val_accuracy: 0.3335
# Epoch 6/100
#  - 0s - loss: 1.1019 - accuracy: 0.3300 - val_loss: 1.1019 - val_accuracy: 0.3385
# Epoch 7/100
#  - 0s - loss: 1.1018 - accuracy: 0.3266 - val_loss: 1.1019 - val_accuracy: 0.3425
# Epoch 8/100
#  - 0s - loss: 1.1018 - accuracy: 0.3257 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 9/100
#  - 0s - loss: 1.1019 - accuracy: 0.3300 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 10/100
#  - 0s - loss: 1.1020 - accuracy: 0.3224 - val_loss: 1.1026 - val_accuracy: 0.3395
# Epoch 11/100
#  - 0s - loss: 1.1017 - accuracy: 0.3340 - val_loss: 1.1019 - val_accuracy: 0.3335
# Epoch 12/100
#  - 0s - loss: 1.1018 - accuracy: 0.3301 - val_loss: 1.1015 - val_accuracy: 0.3335
# Epoch 13/100
#  - 0s - loss: 1.1018 - accuracy: 0.3322 - val_loss: 1.1020 - val_accuracy: 0.3335
# Epoch 14/100
#  - 0s - loss: 1.1018 - accuracy: 0.3313 - val_loss: 1.1020 - val_accuracy: 0.3735
# Epoch 15/100
#  - 0s - loss: 1.1018 - accuracy: 0.3335 - val_loss: 1.1017 - val_accuracy: 0.3380
# Epoch 16/100
#  - 0s - loss: 1.1017 - accuracy: 0.3331 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 17/100
#  - 0s - loss: 1.1019 - accuracy: 0.3354 - val_loss: 1.1019 - val_accuracy: 0.2930
# Epoch 18/100
#  - 0s - loss: 1.1019 - accuracy: 0.3310 - val_loss: 1.1016 - val_accuracy: 0.3330
# Epoch 19/100
#  - 0s - loss: 1.1017 - accuracy: 0.3299 - val_loss: 1.1018 - val_accuracy: 0.3300
# Epoch 20/100
#  - 0s - loss: 1.1016 - accuracy: 0.3421 - val_loss: 1.1016 - val_accuracy: 0.3330
# Epoch 21/100
#  - 0s - loss: 1.1018 - accuracy: 0.3374 - val_loss: 1.1017 - val_accuracy: 0.3330
# Epoch 22/100
#  - 0s - loss: 1.1016 - accuracy: 0.3395 - val_loss: 1.1017 - val_accuracy: 0.3585
# Epoch 23/100
#  - 0s - loss: 1.1017 - accuracy: 0.3275 - val_loss: 1.1027 - val_accuracy: 0.3225
# Epoch 24/100
#  - 0s - loss: 1.1017 - accuracy: 0.3289 - val_loss: 1.1019 - val_accuracy: 0.3390
# Epoch 25/100
#  - 0s - loss: 1.1016 - accuracy: 0.3335 - val_loss: 1.1017 - val_accuracy: 0.3415
# Epoch 26/100
#  - 0s - loss: 1.1018 - accuracy: 0.3313 - val_loss: 1.1018 - val_accuracy: 0.3380
# Epoch 27/100
#  - 0s - loss: 1.1016 - accuracy: 0.3315 - val_loss: 1.1019 - val_accuracy: 0.3280
# Epoch 28/100
#  - 0s - loss: 1.1016 - accuracy: 0.3293 - val_loss: 1.1013 - val_accuracy: 0.3330
# Epoch 29/100
#  - 0s - loss: 1.1019 - accuracy: 0.3321 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 30/100
#  - 0s - loss: 1.1017 - accuracy: 0.3269 - val_loss: 1.1018 - val_accuracy: 0.3335
# Epoch 31/100
#  - 0s - loss: 1.1016 - accuracy: 0.3249 - val_loss: 1.1013 - val_accuracy: 0.3330
# Epoch 32/100
#  - 0s - loss: 1.1016 - accuracy: 0.3327 - val_loss: 1.1012 - val_accuracy: 0.3485
# Epoch 33/100
#  - 0s - loss: 1.1017 - accuracy: 0.3339 - val_loss: 1.1025 - val_accuracy: 0.3480
# Epoch 34/100
#  - 0s - loss: 1.1017 - accuracy: 0.3442 - val_loss: 1.1020 - val_accuracy: 0.3360
# Epoch 35/100
#  - 0s - loss: 1.1022 - accuracy: 0.3338 - val_loss: 1.1015 - val_accuracy: 0.3715
# Epoch 36/100
#  - 0s - loss: 1.1018 - accuracy: 0.3352 - val_loss: 1.1014 - val_accuracy: 0.3330
# Epoch 37/100
#  - 0s - loss: 1.1017 - accuracy: 0.3339 - val_loss: 1.1011 - val_accuracy: 0.3445
# Epoch 38/100
#  - 0s - loss: 1.1018 - accuracy: 0.3315 - val_loss: 1.1016 - val_accuracy: 0.3335
# Epoch 39/100
#  - 0s - loss: 1.1015 - accuracy: 0.3334 - val_loss: 1.1016 - val_accuracy: 0.3335
# Epoch 40/100
#  - 0s - loss: 1.1015 - accuracy: 0.3254 - val_loss: 1.1016 - val_accuracy: 0.3320
# Epoch 41/100
#  - 0s - loss: 1.1015 - accuracy: 0.3280 - val_loss: 1.1016 - val_accuracy: 0.3330
# Epoch 42/100
#  - 0s - loss: 1.1014 - accuracy: 0.3288 - val_loss: 1.1017 - val_accuracy: 0.3330
# Epoch 43/100
#  - 0s - loss: 1.1014 - accuracy: 0.3223 - val_loss: 1.1016 - val_accuracy: 0.3330
# Epoch
# Epoch 13/100
#  - 0s - loss: 1.1018 - accuracy: 0.3316 - val_loss: 1.1016 - val_accuracy: 0.3340
# Epoch 14/100
#  - 0s - loss: 1.1018 - accuracy: 0.3299 - val_loss: 1.1010 - val_accuracy: 0.3490
# Epoch 15/100
#  - 0s - loss: 1.1017 - accuracy: 0.3385 - val_loss: 1.1015 - val_accuracy: 0.3490
# Epoch 16/100
#  - 0s - loss: 1.1017 - accuracy: 0.3339 - val_loss: 1.1013 - val_accuracy: 0.3400
# Epoch 17/100
#  - 0s - loss: 1.1017 - accuracy: 0.3360 - val_loss: 1.1016 - val_accuracy: 0.3645
# Epoch 18/100
#  - 0s - loss: 1.1017 - accuracy: 0.3363 - val_loss: 1.1015 - val_accuracy: 0.3385
# Epoch 19/100
#  - 0s - loss: 1.1017 - accuracy: 0.3274 - val_loss: 1.1013 - val_accuracy: 0.3535
# Epoch 20/100
#  - 0s - loss: 1.1016 - accuracy: 0.3352 - val_loss: 1.1012 - val_accuracy: 0.3330
# Epoch 21/100
#  - 0s - loss: 1.1017 - accuracy: 0.3376 - val_loss: 1.1015 - val_accuracy: 0.3330
# Epoch 22/100
#  - 0s - loss: 1.1019 - accuracy: 0.3371 - val_loss: 1.1018 - val_accuracy: 0.3275
# Epoch 23/100
#  - 0s - loss: 1.1017 - accuracy: 0.3361 - val_loss: 1.1016 - val_accuracy: 0.3640
# Epoch 24/100
#  - 0s - loss: 1.1020 - accuracy: 0.3274 - val_loss: 1.1015 - val_accuracy: 0.3170
# Epoch 25/100
#  - 0s - loss: 1.1017 - accuracy: 0.3440 - val_loss: 1.1012 - val_accuracy: 0.3595
# Epoch 26/100
#  - 0s - loss: 1.1018 - accuracy: 0.3450 - val_loss: 1.1011 - val_accuracy: 0.3460
# Epoch 27/100
#  - 0s - loss: 1.1022 - accuracy: 0.3350 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 28/100
#  - 0s - loss: 1.1017 - accuracy: 0.3444 - val_loss: 1.1015 - val_accuracy: 0.3455
# Epoch 29/100
#  - 0s - loss: 1.1018 - accuracy: 0.3451 - val_loss: 1.1016 - val_accuracy: 0.3325
# Epoch 30/100
#  - 0s - loss: 1.1016 - accuracy: 0.3481 - val_loss: 1.1014 - val_accuracy: 0.3750
# Epoch 31/100
#  - 0s - loss: 1.1016 - accuracy: 0.3487 - val_loss: 1.1010 - val_accuracy: 0.3535
# Epoch 32/100
#  - 0s - loss: 1.1017 - accuracy: 0.3487 - val_loss: 1.1012 - val_accuracy: 0.3640
# Epoch 33/100
#  - 0s - loss: 1.1016 - accuracy: 0.3458 - val_loss: 1.1005 - val_accuracy: 0.3610
# Epoch 34/100
#  - 0s - loss: 1.1015 - accuracy: 0.3530 - val_loss: 1.1002 - val_accuracy: 0.3645
# Epoch 35/100
#  - 0s - loss: 1.1018 - accuracy: 0.3481 - val_loss: 1.1002 - val_accuracy: 0.3550
# Epoch 36/100
#  - 0s - loss: 1.1016 - accuracy: 0.3528 - val_loss: 1.1036 - val_accuracy: 0.3310
# Epoch 37/100
#  - 0s - loss: 1.1020 - accuracy: 0.3442 - val_loss: 1.0995 - val_accuracy: 0.3570
# Epoch 38/100
#  - 0s - loss: 1.1010 - accuracy: 0.3498 - val_loss: 1.1015 - val_accuracy: 0.3680
# Epoch 39/100
#  - 0s - loss: 1.1013 - accuracy: 0.3475 - val_loss: 1.0995 - val_accuracy: 0.3600
# Epoch 40/100
#  - 0s - loss: 1.1013 - accuracy: 0.3484 - val_loss: 1.0995 - val_accuracy: 0.3715
# Epoch 41/100
#  - 0s - loss: 1.1006 - accuracy: 0.3537 - val_loss: 1.0994 - val_accuracy: 0.3650
# Epoch 42/100
#  - 0s - loss: 1.1006 - accuracy: 0.3507 - val_loss: 1.0999 - val_accuracy: 0.3700
# Epoch 43/100
#  - 0s - loss: 1.1018 - accuracy: 0.3478 - val_loss: 1.1000 - val_accuracy: 0.3630
# Epoch 44/100
#  - 0s - loss: 1.1008 - accuracy: 0.3503 - val_loss: 1.1009 - val_accuracy: 0.3430
# Epoch 45/100
#  - 0s - loss: 1.1007 - accuracy: 0.3564 - val_loss: 1.1036 - val_accuracy: 0.3145
# Epoch 46/100
#  - 0s - loss: 1.1009 - accuracy: 0.3520 - val_loss: 1.0984 - val_accuracy: 0.3700
# Epoch 47/100
#  - 0s - loss: 1.1002 - accuracy: 0.3604 - val_loss: 1.0977 - val_accuracy: 0.3820
# Epoch 48/100
#  - 0s - loss: 1.1007 - accuracy: 0.3555 - val_loss: 1.1035 - val_accuracy: 0.3330
# Epoch 49/100
#  - 0s - loss: 1.1009 - accuracy: 0.3559 - val_loss: 1.0979 - val_accuracy: 0.3860
# Epoch 50/100
#  - 0s - loss: 1.0998 - accuracy: 0.3604 - val_loss: 1.0966 - val_accuracy: 0.3815
# Epoch 51/100
#  - 0s - loss: 1.1000 - accuracy: 0.3565 - val_loss: 1.0988 - val_accuracy: 0.3765
# Epoch 52/100
#  - 0s - loss: 1.1006 - accuracy: 0.3571 - val_loss: 1.0978 - val_accuracy: 0.3705
# Epoch 53/100
#  - 0s - loss: 1.0997 - accuracy: 0.3599 - val_loss: 1.0979 - val_accuracy: 0.3720
# Epoch 54/100
#  - 0s - loss: 1.1000 - accuracy: 0.3585 - val_loss: 1.0985 - val_accuracy: 0.3680
# Epoch 55/100
#  - 0s - loss: 1.1001 - accuracy: 0.3553 - val_loss: 1.0991 - val_accuracy: 0.3555
# Epoch 56/100
#  - 0s - loss: 1.1003 - accuracy: 0.3546 - val_loss: 1.0977 - val_accuracy: 0.3680
# Epoch 57/100
#  - 0s - loss: 1.1003 - accuracy: 0.3624 - val_loss: 1.1014 - val_accuracy: 0.3330
# Epoch 58/100
#  - 0s - loss: 1.1003 - accuracy: 0.3517 - val_loss: 1.0974 - val_accuracy: 0.3885
# Epoch 59/100
#  - 0s - loss: 1.0998 - accuracy: 0.3530 - val_loss: 1.0998 - val_accuracy: 0.3550
# Epoch 60/100
#  - 0s - loss: 1.1000 - accuracy: 0.3581 - val_loss: 1.0996 - val_accuracy: 0.3485
# Epoch 61/100
#  - 0s - loss: 1.0993 - accuracy: 0.3640 - val_loss: 1.0971 - val_accuracy: 0.3760
# Epoch 62/100
#  - 0s - loss: 1.1000 - accuracy: 0.3629 - val_loss: 1.0969 - val_accuracy: 0.3755
# Epoch 63/100
#  - 0s - loss: 1.0990 - accuracy: 0.3641 - val_loss: 1.0960 - val_accuracy: 0.3870
# Epoch 64/100
#  - 0s - loss: 1.0995 - accuracy: 0.3548 - val_loss: 1.0964 - val_accuracy: 0.3780
# Epoch 65/100
#  - 0s - loss: 1.1004 - accuracy: 0.3565 - val_loss: 1.0968 - val_accuracy: 0.3870
# Epoch 66/100
#  - 0s - loss: 1.0989 - accuracy: 0.3641 - val_loss: 1.0970 - val_accuracy: 0.3620
# Epoch 67/100
#  - 0s - loss: 1.0991 - accuracy: 0.3586 - val_loss: 1.0958 - val_accuracy: 0.3745
# Epoch 68/100
#  - 0s - loss: 1.0992 - accuracy: 0.3646 - val_loss: 1.0987 - val_accuracy: 0.3550
# Epoch 69/100
#  - 0s - loss: 1.0995 - accuracy: 0.3594 - val_loss: 1.0999 - val_accuracy: 0.3465
# Epoch 70/100
#  - 0s - loss: 1.0994 - accuracy: 0.3661 - val_loss: 1.0970 - val_accuracy: 0.3745
# Epoch 71/100
#  - 0s - loss: 1.0990 - accuracy: 0.3577 - val_loss: 1.0973 - val_accuracy: 0.3645
# Epoch 72/100
#  - 0s - loss: 1.0987 - accuracy: 0.3619 - val_loss: 1.0954 - val_accuracy: 0.3805
# Epoch 73/100
#  - 0s - loss: 1.0991 - accuracy: 0.3616 - val_loss: 1.0957 - val_accuracy: 0.3775
# Epoch 74/100
#  - 0s - loss: 1.1001 - accuracy: 0.3540 - val_loss: 1.0972 - val_accuracy: 0.3735
# Epoch 75/100
#  - 0s - loss: 1.0994 - accuracy: 0.3619 - val_loss: 1.0973 - val_accuracy: 0.3710
# Epoch 76/100
#  - 0s - loss: 1.0989 - accuracy: 0.3602 - val_loss: 1.1050 - val_accuracy: 0.3390
# Epoch 77/100
#  - 0s - loss: 1.0987 - accuracy: 0.3668 - val_loss: 1.0974 - val_accuracy: 0.3745
# Epoch 78/100
#  - 0s - loss: 1.0986 - accuracy: 0.3660 - val_loss: 1.0975 - val_accuracy: 0.3635
# Epoch 79/100
#  - 0s - loss: 1.1009 - accuracy: 0.3594 - val_loss: 1.0963 - val_accuracy: 0.3690
# Epoch 80/100
#  - 0s - loss: 1.0984 - accuracy: 0.3643 - val_loss: 1.0979 - val_accuracy: 0.3610
# Epoch 81/100
#  - 0s - loss: 1.0983 - accuracy: 0.3654 - val_loss: 1.0959 - val_accuracy: 0.3850
# Epoch 82/100
#  - 0s - loss: 1.0982 - accuracy: 0.3644 - val_loss: 1.0971 - val_accuracy: 0.3835
# Epoch 83/100
#  - 0s - loss: 1.0983 - accuracy: 0.3660 - val_loss: 1.0988 - val_accuracy: 0.3710
# Epoch 84/100
#  - 0s - loss: 1.0995 - accuracy: 0.3625 - val_loss: 1.0960 - val_accuracy: 0.3900
# Epoch 85/100
#  - 0s - loss: 1.0981 - accuracy: 0.3728 - val_loss: 1.0981 - val_accuracy: 0.3740
# Epoch 86/100
#  - 0s - loss: 1.0990 - accuracy: 0.3661 - val_loss: 1.0945 - val_accuracy: 0.3970
# Epoch 87/100
#  - 0s - loss: 1.0977 - accuracy: 0.3736 - val_loss: 1.0964 - val_accuracy: 0.3850
# Epoch 88/100
#  - 0s - loss: 1.0995 - accuracy: 0.3706 - val_loss: 1.0972 - val_accuracy: 0.3835
# Epoch 89/100
#  - 0s - loss: 1.0985 - accuracy: 0.3696 - val_loss: 1.0943 - val_accuracy: 0.3860
# Epoch 90/100
#  - 0s - loss: 1.0979 - accuracy: 0.3719 - val_loss: 1.0990 - val_accuracy: 0.3575
# Epoch 91/100
#  - 0s - loss: 1.0972 - accuracy: 0.3747 - val_loss: 1.0983 - val_accuracy: 0.3720
# Epoch 92/100
#  - 0s - loss: 1.0998 - accuracy: 0.3704 - val_loss: 1.0964 - val_accuracy: 0.3810
# Epoch 93/100
#  - 0s - loss: 1.0979 - accuracy: 0.3691 - val_loss: 1.0953 - val_accuracy: 0.3900
# Epoch 94/100
#  - 0s - loss: 1.0982 - accuracy: 0.3661 - val_loss: 1.0969 - val_accuracy: 0.3775
# Epoch 95/100
#  - 0s - loss: 1.0974 - accuracy: 0.3745 - val_loss: 1.0943 - val_accuracy: 0.3900
# Epoch 96/100
#  - 0s - loss: 1.0975 - accuracy: 0.3783 - val_loss: 1.0942 - val_accuracy: 0.3910
# Epoch 97/100
#  - 0s - loss: 1.0972 - accuracy: 0.3771 - val_loss: 1.0952 - val_accuracy: 0.3850
# Epoch 98/100
#  - 0s - loss: 1.0964 - accuracy: 0.3784 - val_loss: 1.0932 - val_accuracy: 0.4015
# Epoch 99/100
#  - 0s - loss: 1.0977 - accuracy: 0.3696 - val_loss: 1.1002 - val_accuracy: 0.3770
# Epoch 100/100
#  - 0s - loss: 1.0969 - accuracy: 0.3730 - val_loss: 1.0935 - val_accuracy: 0.3840

# %%
# Grafical comparison

fits = [fit2,fit4,fit6]

plt.close()

# Accuracy
plt.figure(figsize=(10,8))
for fit, test in zip(fits,tests_plot[1::2]):
    
    plt.plot(fit.history['accuracy'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_accuracy'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('accuracy', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='lower right', fontsize=fontsize)    
plt.show()

# Loss
plt.figure(figsize=(10,8))
for fit, test in zip(fits,tests_plot[1::2]):
    
    plt.plot(fit.history['loss'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_loss'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('loss', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='upper right', fontsize=fontsize)    
plt.show()

# %% [markdown]
# #### Comment
# From the learning process, it seems that the `t2` model, the one with 2 convolutional layers and 2 fully connected layers (recall, it has less parameters than `t4`) is the one performing better in the long run, having an accuracy greater that the other models!
#
# The fastest to learn is `t4` related to 1 convolutional layer and 1 fully connected layer but is the worst in the long run. While `t6`, which is like the one used during lessons `3_0X`, stays in the middle.

# %% [markdown]
# ## 2: Confusion Matrix
#
# As it can be seen from the [relative documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html), the `sklearn.metrics.confusion_matrix` function evaluates classification accuracy by computing the confusion matrix with each row corresponding to the true class, and each column corresponding to the predected one. Notice that [Wikipedia](https://en.wikipedia.org/wiki/Confusion_matrix) and other references may use different convention for axes.
#
# By definition, entry $C_{ij}$ in a confusion matrix $C$ is the number of observations actually in group $i$, but predicted to be in group $j$. Therefore, the diagonal elements represent the number of points for which the predicted label is equal to the true label, while off-diagonal elements are those that are mislabeled by the classifier. The higher the diagonal values of the confusion matrix the better, indicating many correct predictions.
#
# We compute the confusion matrix for the model2, which was the one with the best performance.

# %%
from sklearn.metrics import confusion_matrix

# Uncomment to have a look at the test (val) data one more time:
#print('x, of shape {}: \n'.format(x_val.shape), x_val, '\n')
#print('y, of shape {}: \n'.format(y.shape), y_val, '\n')

y_pred = model2.predict(x_val, batch_size = batch_size)
print('The predicted values are:\n', y_pred)
# Out:
# The predicted values are:
#  [[0.33264208 0.33410034 0.33325756]
#  [0.33264208 0.33410034 0.33325756]
#  [0.33264208 0.33410034 0.33325756]
#  ...
#  [0.33264208 0.33410034 0.33325756]
#  [0.33264208 0.33410034 0.33325756]
#  [0.33264208 0.33410034 0.33325756]]

# %% [markdown]
# In order to compute the confusion matrix, we feed to the confusion_matrix function the index of the maximum value for each row, both for the true labels and for the predicted ones. That index corresponds, moreover, to the wanted category (0 = no signal, 1 = positive signal, 2 = negative signal)

# %%
conf_mat = confusion_matrix(y_val.argmax(axis=1), y_pred.argmax(axis=1))
print(conf_mat)
# Out:
# [[  0 667   0]
#  [  0 666   0]
#  [  0 667   0]]

# %% [markdown]
# Let's do a rapid check: we compute the accuracy of the model as given by the confusion matrix, and visually compare it to the one plotted previously.

# %%
# Sum the element on the diagonal
sum_diag = np.sum(np.diag(conf_mat)) 
# Sum the offdiagonal terms
sum_offd = np.sum(np.extract(1-np.eye(3), conf_mat))

total_n = sum_diag + sum_offd
# Check if it equals the length of y_val (as it should be):
# total_n == len(y_val)

# Computing and printing the accuracy
print('The percentage of corrected categorized data is {} %'.format(100*sum_diag/total_n) )
# Out:
# The percentage of corrected categorized data is 33.3 %

# %% [markdown]
# The result is, therefore, qualitatively consistent.
#
# Let's plot the confusion matrix:

# %%
import seaborn as sns
import pandas as pd

# Feed the confusion matrix into a pandas dataframe, to ease the labeling process in the plot
df_cm = pd.DataFrame(conf_mat, columns = ['Absent', 'Positive', 'Negative'],
                    index = ['Absent', 'Positive', 'Negative'])

plt.figure(figsize=(10,8))
sns.set(font_scale=1.4) # for label size
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap="coolwarm",
           linewidths=.5)
plt.title("Confusion matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()

# %% [markdown]
# ## 3. Regularization
# With two convolutional layers, plot also the weights of the second layer and try to see if regularization may improve the performances by varying the parameter lambda of the L1 or of the L2 regularization; Is any value of lambda good? Is there any intermediate value where the performances of the network are better? Is there any improvement in the visualization and understanding of the weights in the filters?

# %%
def create_regmodel(NCONV=2, n_dense_layers=1, kernel_size_diff=1, summary=False, reg=regularizers.l1(0.1)):

    if n_dense_layers < 1:
        raise('n_dense_layer must be int and >= 1')
        
    # Used to initialize kernel 
    init = initializers.RandomNormal(mean = 0,
                                   stddev = .05)
    model = Sequential()
    model.add( Conv1D(filters=5,
                      kernel_size = 11,                              
                      kernel_initializer = init,
                      kernel_regularizer = reg,
                      activation = 'relu',
                      input_shape = input_size
                     ) )
    model.add( AveragePooling1D(5) ) # max pooling windows' size
    model.add( Flatten() )
    for _ in range(n_dense_layers): # variable number of layers
        model.add( Dense(10, activation='relu') )
    model.add( Dropout(0.2) )
    
    # Output layer
    model.add(Dense(n_class, activation='softmax')) 
    
    # print model's details
    if summary: print(model.summary())
    # Number of trainable parameters
    trainable_count = count_params(model.trainable_weights)
    
    # Compiling model
    opt = optimizers.Nadam()
    model.compile( loss = categorical_crossentropy,
              optimizer = opt,
              metrics = ['accuracy'])
    
    return (model, trainable_count)

# %%
# import regularizers
from keras.regularizers import l1, l2, l1_l2
# instantiate regularizer
reg11 = l1(0.0001)
reg12 = l1(0.001)
reg13 = l1(0.01)
reg21 = l2(0.0001)
reg22 = l2(0.001)
reg23 = l2(0.01)
reg3 = l1_l2(0.01,0.001)

model_l1_1, _ = create_regmodel(**t4,reg=reg11)
model_l1_2, _ = create_regmodel(**t4,reg=reg12)
model_l1_3, _ = create_regmodel(**t4,reg=reg13)
model_l2_1, _ = create_regmodel(**t4,reg=reg21)
model_l2_2, _ = create_regmodel(**t4,reg=reg22)
model_l2_3, _ = create_regmodel(**t4,reg=reg23)
model_l1_l2, _ = create_regmodel(**t4,reg=reg3)

# %%
# retrieve weights from the second hidden layer
fits = []
model_list=[model_l1_1,model_l1_2,model_l1_3,model_l2_1,model_l2_2,model_l2_3, model_l1_l2]
for model in model_list:
    fits.append(model.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
               validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 0s - loss: 1.1022 - accuracy: 0.3444 - val_loss: 1.0901 - val_accuracy: 0.3785
# Epoch 2/100
#  - 0s - loss: 1.0863 - accuracy: 0.3880 - val_loss: 1.0769 - val_accuracy: 0.4240
# Epoch 3/100
#  - 0s - loss: 1.0735 - accuracy: 0.4255 - val_loss: 1.0574 - val_accuracy: 0.4630
# Epoch 4/100
#  - 0s - loss: 1.0558 - accuracy: 0.4469 - val_loss: 1.0383 - val_accuracy: 0.4955
# Epoch 5/100
#  - 0s - loss: 1.0361 - accuracy: 0.4672 - val_loss: 1.0175 - val_accuracy: 0.5020
# Epoch 6/100
#  - 0s - loss: 1.0181 - accuracy: 0.4897 - val_loss: 1.0004 - val_accuracy: 0.5130
# Epoch 7/100
#  - 0s - loss: 1.0037 - accuracy: 0.4963 - val_loss: 0.9897 - val_accuracy: 0.5170
# Epoch 8/100
#  - 0s - loss: 0.9954 - accuracy: 0.5033 - val_loss: 0.9826 - val_accuracy: 0.5170
# Epoch 9/100
#  - 0s - loss: 0.9849 - accuracy: 0.5189 - val_loss: 0.9787 - val_accuracy: 0.5175
# Epoch 10/100
#  - 0s - loss: 0.9783 - accuracy: 0.5231 - val_loss: 0.9735 - val_accuracy: 0.5245
# Epoch 11/100
#  - 0s - loss: 0.9771 - accuracy: 0.5163 - val_loss: 0.9729 - val_accuracy: 0.5255
# Epoch 12/100
#  - 0s - loss: 0.9740 - accuracy: 0.5242 - val_loss: 0.9722 - val_accuracy: 0.5205
# Epoch 13/100
#  - 0s - loss: 0.9700 - accuracy: 0.5270 - val_loss: 0.9673 - val_accuracy: 0.5295
# Epoch 14/100
#  - 0s - loss: 0.9677 - accuracy: 0.5260 - val_loss: 0.9680 - val_accuracy: 0.5325
# Epoch 15/100
#  - 0s - loss: 0.9643 - accuracy: 0.5381 - val_loss: 0.9682 - val_accuracy: 0.5310
# Epoch 16/100
#  - 0s - loss: 0.9613 - accuracy: 0.5395 - val_loss: 0.9670 - val_accuracy: 0.5245
# Epoch 17/100
#  - 0s - loss: 0.9616 - accuracy: 0.5370 - val_loss: 0.9645 - val_accuracy: 0.5380
# Epoch 18/100
#  - 0s - loss: 0.9602 - accuracy: 0.5395 - val_loss: 0.9636 - val_accuracy: 0.5325
# Epoch 19/100
#  - 0s - loss: 0.9563 - accuracy: 0.5400 - val_loss: 0.9616 - val_accuracy: 0.5395
# Epoch 20/100
#  - 0s - loss: 0.9503 - accuracy: 0.5510 - val_loss: 0.9574 - val_accuracy: 0.5410
# Epoch 21/100
#  - 0s - loss: 0.9520 - accuracy: 0.5444 - val_loss: 0.9629 - val_accuracy: 0.5435
# Epoch 22/100
#  - 0s - loss: 0.9516 - accuracy: 0.5496 - val_loss: 0.9562 - val_accuracy: 0.5565
# Epoch 23/100
#  - 0s - loss: 0.9496 - accuracy: 0.5571 - val_loss: 0.9526 - val_accuracy: 0.5450
# Epoch 24/100
#  - 0s - loss: 0.9472 - accuracy: 0.5566 - val_loss: 0.9501 - val_accuracy: 0.5530
# Epoch 25/100
#  - 0s - loss: 0.9450 - accuracy: 0.5534 - val_loss: 0.9506 - val_accuracy: 0.5555
# Epoch 26/100
#  - 0s - loss: 0.9449 - accuracy: 0.5561 - val_loss: 0.9512 - val_accuracy: 0.5500
# Epoch 27/100
#  - 0s - loss: 0.9401 - accuracy: 0.5609 - val_loss: 0.9482 - val_accuracy: 0.5590
# Epoch 28/100
#  - 0s - loss: 0.9442 - accuracy: 0.5585 - val_loss: 0.9469 - val_accuracy: 0.5570
# Epoch 29/100
#  - 0s - loss: 0.9367 - accuracy: 0.5566 - val_loss: 0.9426 - val_accuracy: 0.5635
# Epoch 30/100
#  - 0s - loss: 0.9373 - accuracy: 0.5608 - val_loss: 0.9469 - val_accuracy: 0.5605
# Epoch 31/100
#  - 0s - loss: 0.9321 - accuracy: 0.5698 - val_loss: 0.9394 - val_accuracy: 0.5675
# Epoch 32/100
#  - 0s - loss: 0.9323 - accuracy: 0.5656 - val_loss: 0.9386 - val_accuracy: 0.5725
# Epoch 33/100
#  - 0s - loss: 0.9288 - accuracy: 0.5702 - val_loss: 0.9360 - val_accuracy: 0.5795
# Epoch 34/100
#  - 0s - loss: 0.9280 - accuracy: 0.5670 - val_loss: 0.9351 - val_accuracy: 0.5660
# Epoch 35/100
#  - 0s - loss: 0.9273 - accuracy: 0.5663 - val_loss: 0.9341 - val_accuracy: 0.5745
#  - 0s - loss: 1.0531 - accuracy: 0.4507 - val_loss: 1.0448 - val_accuracy: 0.4740
# Epoch 8/100
#  - 0s - loss: 1.0360 - accuracy: 0.4666 - val_loss: 1.0254 - val_accuracy: 0.5075
# Epoch 9/100
#  - 0s - loss: 1.0252 - accuracy: 0.4800 - val_loss: 1.0089 - val_accuracy: 0.5210
# Epoch 10/100
#  - 0s - loss: 1.0106 - accuracy: 0.4961 - val_loss: 0.9988 - val_accuracy: 0.5325
# Epoch 11/100
#  - 0s - loss: 0.9957 - accuracy: 0.5065 - val_loss: 0.9922 - val_accuracy: 0.5225
# Epoch 12/100
#  - 0s - loss: 0.9878 - accuracy: 0.5106 - val_loss: 0.9804 - val_accuracy: 0.5400
# Epoch 13/100
#  - 0s - loss: 0.9867 - accuracy: 0.5173 - val_loss: 0.9759 - val_accuracy: 0.5355
# Epoch 14/100
#  - 0s - loss: 0.9770 - accuracy: 0.5239 - val_loss: 0.9724 - val_accuracy: 0.5415
# Epoch 15/100
#  - 0s - loss: 0.9708 - accuracy: 0.5296 - val_loss: 0.9691 - val_accuracy: 0.5520
# Epoch 16/100
#  - 0s - loss: 0.9690 - accuracy: 0.5293 - val_loss: 0.9620 - val_accuracy: 0.5520
# Epoch 17/100
#  - 0s - loss: 0.9660 - accuracy: 0.5332 - val_loss: 0.9608 - val_accuracy: 0.5500
# Epoch 18/100
#  - 0s - loss: 0.9628 - accuracy: 0.5406 - val_loss: 0.9585 - val_accuracy: 0.5590
# Epoch 19/100
#  - 0s - loss: 0.9605 - accuracy: 0.5400 - val_loss: 0.9529 - val_accuracy: 0.5560
# Epoch 20/100
#  - 0s - loss: 0.9553 - accuracy: 0.5484 - val_loss: 0.9508 - val_accuracy: 0.5625
# Epoch 21/100
#  - 0s - loss: 0.9477 - accuracy: 0.5452 - val_loss: 0.9471 - val_accuracy: 0.5610
# Epoch 22/100
#  - 0s - loss: 0.9517 - accuracy: 0.5472 - val_loss: 0.9453 - val_accuracy: 0.5650
# Epoch 23/100
#  - 0s - loss: 0.9476 - accuracy: 0.5475 - val_loss: 0.9433 - val_accuracy: 0.5630
# Epoch 24/100
#  - 0s - loss: 0.9467 - accuracy: 0.5525 - val_loss: 0.9442 - val_accuracy: 0.5555
# Epoch 25/100
#  - 0s - loss: 0.9415 - accuracy: 0.5581 - val_loss: 0.9417 - val_accuracy: 0.5735
# Epoch 26/100
#  - 0s - loss: 0.9400 - accuracy: 0.5580 - val_loss: 0.9401 - val_accuracy: 0.5740
# Epoch 27/100
#  - 0s - loss: 0.9396 - accuracy: 0.5540 - val_loss: 0.9432 - val_accuracy: 0.5680
# Epoch 28/100
#  - 0s - loss: 0.9396 - accuracy: 0.5575 - val_loss: 0.9390 - val_accuracy: 0.5635
# Epoch 29/100
#  - 0s - loss: 0.9348 - accuracy: 0.5575 - val_loss: 0.9381 - val_accuracy: 0.5700
# Epoch 30/100
#  - 0s - loss: 0.9374 - accuracy: 0.5589 - val_loss: 0.9364 - val_accuracy: 0.5725
# Epoch 31/100
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 0s - loss: 1.1052 - accuracy: 0.3341 - val_loss: 1.0947 - val_accuracy: 0.3590
# Epoch 2/100
#  - 0s - loss: 1.0897 - accuracy: 0.3740 - val_loss: 1.0873 - val_accuracy: 0.3945
# Epoch 3/100
#  - 0s - loss: 1.0797 - accuracy: 0.4035 - val_loss: 1.0791 - val_accuracy: 0.4095
# Epoch 4/100
#  - 0s - loss: 1.0714 - accuracy: 0.4146 - val_loss: 1.0675 - val_accuracy: 0.4270
# Epoch 5/100
#  - 0s - loss: 1.0607 - accuracy: 0.4288 - val_loss: 1.0587 - val_accuracy: 0.4470
# Epoch 6/100
#  - 0s - loss: 1.0502 - accuracy: 0.4433 - val_loss: 1.0469 - val_accuracy: 0.4625
# Epoch 7/100
#  - 0s - loss: 1.0376 - accuracy: 0.4638 - val_loss: 1.0330 - val_accuracy: 0.4835
# Epoch 8/100
#  - 0s - loss: 1.0313 - accuracy: 0.4695 - val_loss: 1.0230 - val_accuracy: 0.4940
# Epoch 9/100
#  - 0s - loss: 1.0197 - accuracy: 0.4803 - val_loss: 1.0148 - val_accuracy: 0.4900
# Epoch 10/100
#  - 0s - loss: 1.0062 - accuracy: 0.4970 - val_loss: 1.0024 - val_accuracy: 0.5085
# Epoch 11/100
#  - 0s - loss: 1.0036 - accuracy: 0.4985 - val_loss: 0.9992 - val_accuracy: 0.5045
# Epoch 12/100
#  - 0s - loss: 0.9919 - accuracy: 0.5030 - val_loss: 0.9905 - val_accuracy: 0.5155
# Epoch 13/100
#  - 0s - loss: 0.9916 - accuracy: 0.5023 - val_loss: 0.9882 - val_accuracy: 0.5160
# Epoch 14/100
#  - 0s - loss: 0.9827 - accuracy: 0.5195 - val_loss: 0.9843 - val_accuracy: 0.5305
# Epoch 15/100
#  - 0s - loss: 0.9806 - accuracy: 0.5155 - val_loss: 0.9800 - val_accuracy: 0.5245
# Epoch 16/100
#  - 0s - loss: 0.9740 - accuracy: 0.5250 - val_loss: 0.9747 - val_accuracy: 0.5325
# Epoch 17/100
#  - 0s - loss: 0.9783 - accuracy: 0.5196 - val_loss: 0.9746 - val_accuracy: 0.5345
# Epoch 18/100
#  - 0s - loss: 0.9673 - accuracy: 0.5245 - val_loss: 0.9712 - val_accuracy: 0.5365
# Epoch 19/100
#  - 0s - loss: 0.9644 - accuracy: 0.5291 - val_loss: 0.9677 - val_accuracy: 0.5360
# Epoch 20/100
#  - 0s - loss: 0.9623 - accuracy: 0.5355 - val_loss: 0.9649 - val_accuracy: 0.5450
# Epoch 21/100
#  - 0s - loss: 0.9600 - accuracy: 0.5345 - val_loss: 0.9629 - val_accuracy: 0.5445
# Epoch 22/100
#  - 0s - loss: 0.9550 - accuracy: 0.5441 - val_loss: 0.9621 - val_accuracy: 0.5445
#  - 0s - loss: 0.9057 - accuracy: 0.5817 - val_loss: 0.9213 - val_accuracy: 0.5810
# Epoch 95/100
#  - 0s - loss: 0.9050 - accuracy: 0.5775 - val_loss: 0.9209 - val_accuracy: 0.5820
# Epoch 96/100
#  - 0s - loss: 0.9061 - accuracy: 0.5792 - val_loss: 0.9200 - val_accuracy: 0.5845
# Epoch 97/100
#  - 0s - loss: 0.9069 - accuracy: 0.5791 - val_loss: 0.9219 - val_accuracy: 0.5820
# Epoch 98/100
#  - 0s - loss: 0.9032 - accuracy: 0.5778 - val_loss: 0.9214 - val_accuracy: 0.5895
# Epoch 99/100
#  - 0s - loss: 0.9041 - accuracy: 0.5809 - val_loss: 0.9213 - val_accuracy: 0.5815
# Epoch 100/100
#  - 0s - loss: 0.9071 - accuracy: 0.5764 - val_loss: 0.9195 - val_accuracy: 0.5855
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 0s - loss: 1.1021 - accuracy: 0.3449 - val_loss: 1.0939 - val_accuracy: 0.3720
# Epoch 2/100
#  - 0s - loss: 1.0938 - accuracy: 0.3690 - val_loss: 1.0884 - val_accuracy: 0.3895
# Epoch 3/100
#  - 0s - loss: 1.0854 - accuracy: 0.3839 - val_loss: 1.0796 - val_accuracy: 0.4150
# Epoch 4/100
#  - 0s - loss: 1.0743 - accuracy: 0.4110 - val_loss: 1.0656 - val_accuracy: 0.4615
# Epoch 5/100
#  - 0s - loss: 1.0601 - accuracy: 0.4378 - val_loss: 1.0525 - val_accuracy: 0.4550
# Epoch 6/100
#  - 0s - loss: 1.0463 - accuracy: 0.4576 - val_loss: 1.0370 - val_accuracy: 0.4930
# Epoch 7/100
#  - 0s - loss: 1.0293 - accuracy: 0.4759 - val_loss: 1.0196 - val_accuracy: 0.5110
# Epoch 8/100
#  - 0s - loss: 1.0179 - accuracy: 0.4866 - val_loss: 1.0079 - val_accuracy: 0.5185
# Epoch 9/100
#  - 0s - loss: 1.0066 - accuracy: 0.4986 - val_loss: 0.9959 - val_accuracy: 0.5275
# Epoch 10/100
#  - 0s - loss: 0.9971 - accuracy: 0.4980 - val_loss: 0.9943 - val_accuracy: 0.5360
# Epoch 11/100
#  - 0s - loss: 0.9853 - accuracy: 0.5184 - val_loss: 0.9764 - val_accuracy: 0.5445
# Epoch 12/100
#  - 0s - loss: 0.9824 - accuracy: 0.5205 - val_loss: 0.9675 - val_accuracy: 0.5510
# Epoch 13/100
#  - 0s - loss: 0.9739 - accuracy: 0.5299 - val_loss: 0.9653 - val_accuracy: 0.5530
# Epoch 14/100
#  - 0s - loss: 0.9664 - accuracy: 0.5335 - val_loss: 0.9686 - val_accuracy: 0.5390
# Epoch 15/100
#  - 0s - loss: 0.9643 - accuracy: 0.5353 - val_loss: 0.9540 - val_accuracy: 0.5590
# Epoch 16/100
#  - 0s - loss: 0.9601 - accuracy: 0.5380 - val_loss: 0.9541 - val_accuracy: 0.5655
# Epoch 17/100
#  - 0s - loss: 0.9502 - accuracy: 0.5454 - val_loss: 0.9512 - val_accuracy: 0.5555
# Epoch 18/100
#  - 0s - loss: 0.9519 - accuracy: 0.5444 - val_loss: 0.9476 - val_accuracy: 0.5710
# Epoch 19/100
#  - 0s - loss: 0.9531 - accuracy: 0.5480 - val_loss: 0.9430 - val_accuracy: 0.5745
# Epoch 20/100
#  - 0s - loss: 0.9471 - accuracy: 0.5550 - val_loss: 0.9500 - val_accuracy: 0.5685
# Epoch 21/100
#  - 0s - loss: 0.9438 - accuracy: 0.5571 - val_loss: 0.9385 - val_accuracy: 0.5750
# Epoch 22/100
#  - 0s - loss: 0.9483 - accuracy: 0.5526 - val_loss: 0.9391 - val_accuracy: 0.5680
# Epoch 23/100
#  - 0s - loss: 0.9400 - accuracy: 0.5590 - val_loss: 0.9355 - val_accuracy: 0.5760
# Epoch 24/100
#  - 0s - loss: 0.9374 - accuracy: 0.5633 - val_loss: 0.9322 - val_accuracy: 0.5795
# Epoch 25/100
#  - 0s - loss: 0.9341 - accuracy: 0.5600 - val_loss: 0.9309 - val_accuracy: 0.5725
# Epoch 26/100
#  - 0s - loss: 0.9358 - accuracy: 0.5625 - val_loss: 0.9347 - val_accuracy: 0.5670
# Epoch 27/100
#  - 0s - loss: 0.9307 - accuracy: 0.5660 - val_loss: 0.9284 - val_accuracy: 0.5830
# Epoch 28/100
#  - 0s - loss: 0.9295 - accuracy: 0.5691 - val_loss: 0.9267 - val_accuracy: 0.5835
# Epoch 29/100
#  - 0s - loss: 0.9228 - accuracy: 0.5765 - val_loss: 0.9275 - val_accuracy: 0.5830
# Epoch 30/100
#  - 0s - loss: 0.9259 - accuracy: 0.5681 - val_loss: 0.9244 - val_accuracy: 0.5905
# Epoch 31/100
#  - 0s - loss: 0.9270 - accuracy: 0.5655 - val_loss: 0.9234 - val_accuracy: 0.5830
# Epoch 32/100
#  - 0s - loss: 0.9317 - accuracy: 0.5644 - val_loss: 0.9220 - val_accuracy: 0.5835
# Epoch 33/100
#  - 0s - loss: 0.9183 - accuracy: 0.5760 - val_loss: 0.9216 - val_accuracy: 0.5810
# Epoch 34/100
#  - 0s - loss: 0.9242 - accuracy: 0.5707 - val_loss: 0.9193 - val_accuracy: 0.5850
# Epoch 35/100
#  - 0s - loss: 0.9182 - accuracy: 0.5757 - val_loss: 0.9180 - val_accuracy: 0.5865
# Epoch 36/100
#  - 0s - loss: 0.9221 - accuracy: 0.5755 - val_loss: 0.9178 - val_accuracy: 0.5895
# Epoch 37/100
#  - 0s - loss: 0.9197 - accuracy: 0.5725 - val_loss: 0.9147 - val_accuracy: 0.5895
# Epoch 38/100
#  - 0s - loss: 0.9180 - accuracy: 0.5753 - val_loss: 0.9149 - val_accuracy: 0.5995
# Epoch 39/100
#  - 0s - loss: 0.9130 - accuracy: 0.5788 - val_loss: 0.9134 - val_accuracy: 0.5920
# Epoch 40/100
#  - 0s - loss: 0.9151 - accuracy: 0.5755 - val_loss: 0.9123 - val_accuracy: 0.5975
# Epoch 41/100
#  - 0s - loss: 0.9143 - accuracy: 0.5781 - val_loss: 0.9146 - val_accuracy: 0.5955
# Epoch 42/100
#  - 0s - loss: 0.8700 - accuracy: 0.6060 - val_loss: 0.8788 - val_accuracy: 0.6190
# Epoch 91/100
#  - 0s - loss: 0.8731 - accuracy: 0.6039 - val_loss: 0.8784 - val_accuracy: 0.6205
# Epoch 92/100
#  - 0s - loss: 0.8699 - accuracy: 0.6054 - val_loss: 0.8778 - val_accuracy: 0.6230
# Epoch 93/100
#  - 0s - loss: 0.8660 - accuracy: 0.6068 - val_loss: 0.8799 - val_accuracy: 0.6255
# Epoch 94/100
#  - 0s - loss: 0.8697 - accuracy: 0.6050 - val_loss: 0.8759 - val_accuracy: 0.6200
# Epoch 95/100
#  - 0s - loss: 0.8686 - accuracy: 0.6059 - val_loss: 0.8757 - val_accuracy: 0.6250
# Epoch 96/100
#  - 0s - loss: 0.8679 - accuracy: 0.6112 - val_loss: 0.8762 - val_accuracy: 0.6220
# Epoch 97/100
#  - 0s - loss: 0.8675 - accuracy: 0.6085 - val_loss: 0.8769 - val_accuracy: 0.6170
# Epoch 98/100
#  - 0s - loss: 0.8662 - accuracy: 0.6095 - val_loss: 0.8763 - val_accuracy: 0.6220
# Epoch 99/100
#  - 0s - loss: 0.8672 - accuracy: 0.6118 - val_loss: 0.8756 - val_accuracy: 0.6205
# Epoch 100/100
#  - 0s - loss: 0.8691 - accuracy: 0.6046 - val_loss: 0.8758 - val_accuracy: 0.6210
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 0s - loss: 1.1016 - accuracy: 0.3520 - val_loss: 1.0895 - val_accuracy: 0.3790
# Epoch 2/100
#  - 0s - loss: 1.0864 - accuracy: 0.3864 - val_loss: 1.0788 - val_accuracy: 0.4135
# Epoch 3/100
# ...
#  - 0s - loss: 0.9376 - accuracy: 0.5617 - val_loss: 0.9309 - val_accuracy: 0.5815
# Epoch 34/100
#  - 0s - loss: 0.9288 - accuracy: 0.5716 - val_loss: 0.9285 - val_accuracy: 0.5795
# Epoch 35/100
#  - 0s - loss: 0.9329 - accuracy: 0.5683 - val_loss: 0.9299 - val_accuracy: 0.5815
# Epoch 36/100
#  - 0s - loss: 0.9284 - accuracy: 0.5759 - val_loss: 0.9326 - val_accuracy: 0.5810
# Epoch 37/100
#  - 0s - loss: 0.9284 - accuracy: 0.5700 - val_loss: 0.9278 - val_accuracy: 0.5820
# Epoch 38/100
#  - 0s - loss: 0.9285 - accuracy: 0.5688 - val_loss: 0.9294 - val_accuracy: 0.5815
# Epoch 39/100
#  - 0s - loss: 0.9307 - accuracy: 0.5721 - val_loss: 0.9286 - val_accuracy: 0.5735
# Epoch 40/100
#  - 0s - loss: 0.9258 - accuracy: 0.5734 - val_loss: 0.9284 - val_accuracy: 0.5790
# Epoch 41/100
#  - 0s - loss: 0.9254 - accuracy: 0.5700 - val_loss: 0.9292 - val_accuracy: 0.5730
# Epoch 42/100
#  - 0s - loss: 0.9276 - accuracy: 0.5723 - val_loss: 0.9257 - val_accuracy: 0.5770
# Epoch 43/100
#  - 0s - loss: 0.9260 - accuracy: 0.5721 - val_loss: 0.9296 - val_accuracy: 0.5780
# Epoch 44/100
#  - 0s - loss: 0.9268 - accuracy: 0.5721 - val_loss: 0.9297 - val_accuracy: 0.5770
# Epoch 45/100
#  - 0s - loss: 0.9226 - accuracy: 0.5681 - val_loss: 0.9231 - val_accuracy: 0.5855
# Epoch 46/100
#  - 0s - loss: 0.9255 - accuracy: 0.5686 - val_loss: 0.9244 - val_accuracy: 0.5820
# Epoch 47/100
#  - 0s - loss: 0.9276 - accuracy: 0.5665 - val_loss: 0.9246 - val_accuracy: 0.5835
# Epoch 48/100
#  - 0s - loss: 0.9206 - accuracy: 0.5778 - val_loss: 0.9262 - val_accuracy: 0.5785
# Epoch 49/100
#  - 0s - loss: 0.9254 - accuracy: 0.5757 - val_loss: 0.9246 - val_accuracy: 0.5775
# Epoch 50/100
#  - 0s - loss: 0.9228 - accuracy: 0.5732 - val_loss: 0.9235 - val_accuracy: 0.5785
# Epoch 51/100
#  - 0s - loss: 0.9231 - accuracy: 0.5794 - val_loss: 0.9262 - val_accuracy: 0.5810
# Epoch 52/100
#  - 0s - loss: 0.9210 - accuracy: 0.5760 - val_loss: 0.9233 - val_accuracy: 0.5795
# Epoch 53/100
#  - 0s - loss: 0.9177 - accuracy: 0.5825 - val_loss: 0.9240 - val_accuracy: 0.5760
# Epoch 54/100
#  - 0s - loss: 0.9185 - accuracy: 0.5704 - val_loss: 0.9242 - val_accuracy: 0.5800
# Epoch 55/100
#  - 0s - loss: 0.9190 - accuracy: 0.5759 - val_loss: 0.9212 - val_accuracy: 0.5790
# Epoch 56/100
#  - 0s - loss: 0.9187 - accuracy: 0.5770 - val_loss: 0.9247 - val_accuracy: 0.5800
# Epoch 57/100
#  - 0s - loss: 0.9168 - accuracy: 0.5781 - val_loss: 0.9245 - val_accuracy: 0.5795
# Epoch 58/100
#  - 0s - loss: 0.9141 - accuracy: 0.5774 - val_loss: 0.9246 - val_accuracy: 0.5860
# Epoch 59/100
#  - 0s - loss: 0.9172 - accuracy: 0.5790 - val_loss: 0.9223 - val_accuracy: 0.5845
# Epoch 60/100
#  - 0s - loss: 0.9174 - accuracy: 0.5765 - val_loss: 0.9235 - val_accuracy: 0.5875
# Epoch 61/100
#  - 0s - loss: 0.9172 - accuracy: 0.5825 - val_loss: 0.9227 - val_accuracy: 0.5805
# Epoch 62/100
#  - 0s - loss: 0.9158 - accuracy: 0.5844 - val_loss: 0.9235 - val_accuracy: 0.5835
# Epoch 63/100
#  - 0s - loss: 0.9165 - accuracy: 0.5798 - val_loss: 0.9215 - val_accuracy: 0.5845
# Epoch 64/100
#  - 0s - loss: 0.9176 - accuracy: 0.5784 - val_loss: 0.9243 - val_accuracy: 0.5880
# Epoch 65/100
#  - 0s - loss: 0.9139 - accuracy: 0.5829 - val_loss: 0.9256 - val_accuracy: 0.5835
# Epoch 66/100
#  - 0s - loss: 0.9140 - accuracy: 0.5788 - val_loss: 0.9212 - val_accuracy: 0.5840
# Epoch 67/100
#  - 0s - loss: 0.9145 - accuracy: 0.5825 - val_loss: 0.9251 - val_accuracy: 0.5845
# Epoch 68/100
#  - 0s - loss: 0.9134 - accuracy: 0.5821 - val_loss: 0.9212 - val_accuracy: 0.5820
# Epoch 69/100
#  - 0s - loss: 0.9142 - accuracy: 0.5789 - val_loss: 0.9243 - val_accuracy: 0.5870
# Epoch 70/100
#  - 0s - loss: 0.9118 - accuracy: 0.5840 - val_loss: 0.9225 - val_accuracy: 0.5835
# Epoch 71/100
#  - 0s - loss: 0.9130 - accuracy: 0.5872 - val_loss: 0.9192 - val_accuracy: 0.5825
# Epoch 72/100
#  - 0s - loss: 0.9130 - accuracy: 0.5785 - val_loss: 0.9220 - val_accuracy: 0.5835
# Epoch 73/100
#  - 0s - loss: 0.9097 - accuracy: 0.5831 - val_loss: 0.9192 - val_accuracy: 0.5835
# Epoch 74/100
#  - 0s - loss: 0.9116 - accuracy: 0.5836 - val_loss: 0.9188 - val_accuracy: 0.5855
# Epoch 75/100
#  - 0s - loss: 0.9094 - accuracy: 0.5794 - val_loss: 0.9225 - val_accuracy: 0.5880
# Epoch 76/100
#  - 0s - loss: 0.9066 - accuracy: 0.5860 - val_loss: 0.9190 - val_accuracy: 0.5890
# Epoch 77/100
#  - 0s - loss: 0.9074 - accuracy: 0.5884 - val_loss: 0.9177 - val_accuracy: 0.5900
# Epoch 78/100
#  - 0s - loss: 0.9082 - accuracy: 0.5816 - val_loss: 0.9208 - val_accuracy: 0.5850
# Epoch 79/100
#  - 0s - loss: 0.9132 - accuracy: 0.5839 - val_loss: 0.9210 - val_accuracy: 0.5915
# Epoch 80/100
#  - 0s - loss: 0.9069 - accuracy: 0.5825 - val_loss: 0.9171 - val_accuracy: 0.5990
# Epoch 81/100
#  - 0s - loss: 0.9061 - accuracy: 0.5880 - val_loss: 0.9176 - val_accuracy: 0.5820
# Epoch 82/100
#  - 0s - loss: 0.9106 - accuracy: 0.5884 - val_loss: 0.9157 - val_accuracy: 0.5890
# Epoch 83/100
#  - 0s - loss: 0.9100 - accuracy: 0.5831 - val_loss: 0.9181 - val_accuracy: 0.5885
# Epoch 84/100
#  - 0s - loss: 0.9105 - accuracy: 0.5820 - val_loss: 0.9188 - val_accuracy: 0.5900
# Epoch 85/100
#  - 0s - loss: 0.9064 - accuracy: 0.5891 - val_loss: 0.9155 - val_accuracy: 0.5915
# Epoch 86/100
#  - 0s - loss: 0.9062 - accuracy: 0.5834 - val_loss: 0.9176 - val_accuracy: 0.5915
# Epoch 87/100
#  - 0s - loss: 0.9093 - accuracy: 0.5829 - val_loss: 0.9148 - val_accuracy: 0.5905
# Epoch 88/100
#  - 0s - loss: 0.9086 - accuracy: 0.5855 - val_loss: 0.9152 - val_accuracy: 0.5900
# Epoch 89/100
#  - 0s - loss: 0.9086 - accuracy: 0.5888 - val_loss: 0.9160 - val_accuracy: 0.5960
# Epoch 90/100
#  - 0s - loss: 0.9007 - accuracy: 0.5893 - val_loss: 0.9139 - val_accuracy: 0.5945
# Epoch 91/100
#  - 0s - loss: 0.9017 - accuracy: 0.5897 - val_loss: 0.9169 - val_accuracy: 0.5920
# Epoch 92/100
#  - 0s - loss: 0.9073 - accuracy: 0.5860 - val_loss: 0.9157 - val_accuracy: 0.5915
# Epoch 93/100
#  - 0s - loss: 0.9043 - accuracy: 0.5904 - val_loss: 0.9176 - val_accuracy: 0.5925
# Epoch 94/100
#  - 0s - loss: 0.9039 - accuracy: 0.5921 - val_loss: 0.9167 - val_accuracy: 0.5975
# Epoch 95/100
#  - 0s - loss: 0.9005 - accuracy: 0.5968 - val_loss: 0.9149 - val_accuracy: 0.5895
# Epoch 96/100
#  - 0s - loss: 0.8970 - accuracy: 0.5938 - val_loss: 0.9140 - val_accuracy: 0.5965
# Epoch 97/100
#  - 0s - loss: 0.9072 - accuracy: 0.5890 - val_loss: 0.9155 - val_accuracy: 0.6020
# Epoch 98/100
#  - 0s - loss: 0.9007 - accuracy: 0.5971 - val_loss: 0.9155 - val_accuracy: 0.5905
# Epoch 99/100
#  - 0s - loss: 0.8942 - accuracy: 0.5972 - val_loss: 0.9109 - val_accuracy: 0.5940
# Epoch 100/100
#  - 0s - loss: 0.8988 - accuracy: 0.5893 - val_loss: 0.9111 - val_accuracy: 0.5940
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
#  - 0s - loss: 1.1194 - accuracy: 0.3408 - val_loss: 1.1074 - val_accuracy: 0.3910
# Epoch 2/100
#  - 0s - loss: 1.1040 - accuracy: 0.3772 - val_loss: 1.0967 - val_accuracy: 0.3950
# Epoch 3/100
#  - 0s - loss: 1.0932 - accuracy: 0.3941 - val_loss: 1.0885 - val_accuracy: 0.4060
# Epoch 4/100
#  - 0s - loss: 1.0812 - accuracy: 0.4195 - val_loss: 1.0761 - val_accuracy: 0.4375
# Epoch 5/100
#  - 0s - loss: 1.0688 - accuracy: 0.4449 - val_loss: 1.0702 - val_accuracy: 0.4515
# Epoch 6/100
#  - 0s - loss: 1.0581 - accuracy: 0.4656 - val_loss: 1.0555 - val_accuracy: 0.4615
# Epoch 7/100
#  - 0s - loss: 1.0443 - accuracy: 0.4785 - val_loss: 1.0345 - val_accuracy: 0.4925
# Epoch 8/100
#  - 0s - loss: 1.0333 - accuracy: 0.4914 - val_loss: 1.0294 - val_accuracy: 0.5010
# Epoch 9/100
#  - 0s - loss: 1.0265 - accuracy: 0.4954 - val_loss: 1.0265 - val_accuracy: 0.5115
# Epoch 10/100
#  - 0s - loss: 1.0149 - accuracy: 0.5010 - val_loss: 1.0099 - val_accuracy: 0.5020
# Epoch 11/100
#  - 0s - loss: 1.0122 - accuracy: 0.5046 - val_loss: 1.0109 - val_accuracy: 0.5150
# Epoch 12/100
#  - 0s - loss: 1.0078 - accuracy: 0.5090 - val_loss: 1.0055 - val_accuracy: 0.5255
# Epoch 13/100
#  - 0s - loss: 1.0043 - accuracy: 0.5102 - val_loss: 0.9993 - val_accuracy: 0.5155
# Epoch 14/100
#  - 0s - loss: 1.0016 - accuracy: 0.5200 - val_loss: 0.9979 - val_accuracy: 0.5385
# Epoch 15/100
#  - 0s - loss: 0.9991 - accuracy: 0.5182 - val_loss: 0.9938 - val_accuracy: 0.5250
# Epoch 16/100
#  - 0s - loss: 0.9943 - accuracy: 0.5246 - val_loss: 0.9915 - val_accuracy: 0.5265
# Epoch 17/100
#  - 0s - loss: 0.9907 - accuracy: 0.5282 - val_loss: 0.9899 - val_accuracy: 0.5335
# Epoch 18/100
#  - 0s - loss: 0.9911 - accuracy: 0.5304 - val_loss: 0.9876 - val_accuracy: 0.5425
# Epoch 19/100
#  - 0s - loss: 0.9823 - accuracy: 0.5393 - val_loss: 0.9850 - val_accuracy: 0.5365
# Epoch 20/100
#  - 0s - loss: 0.9856 - accuracy: 0.5387 - val_loss: 0.9818 - val_accuracy: 0.5465
# Epoch 21/100
#  - 0s - loss: 0.9806 - accuracy: 0.5378 - val_loss: 0.9791 - val_accuracy: 0.5380
# Epoch 22/100
#  - 0s - loss: 0.9785 - accuracy: 0.5401 - val_loss: 0.9791 - val_accuracy: 0.5490
# Epoch 23/100
#  - 0s - loss: 0.9792 - accuracy: 0.5430 - val_loss: 0.9798 - val_accuracy: 0.5575
# Epoch 24/100
#  - 0s - loss: 0.9750 - accuracy: 0.5395 - val_loss: 0.9762 - val_accuracy: 0.5545
# Epoch 25/100
#  - 0s - loss: 0.9760 - accuracy: 0.5466 - val_loss: 0.9758 - val_accuracy: 0.5540
# Epoch 26/100
#  - 0s - loss: 0.9758 - accuracy: 0.5434 - val_loss: 0.9753 - val_accuracy: 0.5560
# Epoch 27/100
#  - 0s - loss: 0.9676 - accuracy: 0.5520 - val_loss: 0.9697 - val_accuracy: 0.5615
# Epoch 28/100
#  - 0s - loss: 0.9728 - accuracy: 0.5472 - val_loss: 0.9698 - val_accuracy: 0.5650
# Epoch 29/100
#  - 0s - loss: 0.9695 - accuracy: 0.5496 - val_loss: 0.9717 - val_accuracy: 0.5495
# Epoch 30/100
#  - 0s - loss: 0.9713 - accuracy: 0.5460 - val_loss: 0.9704 - val_accuracy: 0.5555
# Epoch 31/100
#  - 0s - loss: 0.9666 - accuracy: 0.5537 - val_loss: 0.9666 - val_accuracy: 0.5555
# Epoch 32/100
#  - 0s - loss: 0.9683 - accuracy: 0.5477 - val_loss: 0.9722 - val_accuracy: 0.5605
# Epoch 33/100
#  - 0s - loss: 0.9650 - accuracy: 0.5551 - val_loss: 0.9680 - val_accuracy: 0.5620
# Epoch 34/100
#  - 0s - loss: 0.9637 - accuracy: 0.5525 - val_loss: 0.9654 - val_accuracy: 0.5640
# Epoch 35/100
#  - 0s - loss: 0.9676 - accuracy: 0.5504 - val_loss: 0.9657 - val_accuracy: 0.5605
# Epoch 36/100
#  - 0s - loss: 0.9615 - accuracy: 0.5546 - val_loss: 0.9621 - val_accuracy: 0.5610
# Epoch 37/100
#  - 0s - loss: 0.9616 - accuracy: 0.5508 - val_loss: 0.9608 - val_accuracy: 0.5645
# Epoch 38/100
#  - 0s - loss: 0.9661 - accuracy: 0.5525 - val_loss: 0.9636 - val_accuracy: 0.5655
# Epoch 39/100
#  - 0s - loss: 0.9592 - accuracy: 0.5552 - val_loss: 0.9633 - val_accuracy: 0.5695
# Epoch 40/100
#  - 0s - loss: 0.9590 - accuracy: 0.5540 - val_loss: 0.9623 - val_accuracy: 0.5655
# Epoch 41/100
#  - 0s - loss: 0.9583 - accuracy: 0.5515 - val_loss: 0.9626 - val_accuracy: 0.5695
# Epoch 42/100
#  - 0s - loss: 0.9584 - accuracy: 0.5580 - val_loss: 0.9585 - val_accuracy: 0.5640
# Epoch 43/100
#  - 0s - loss: 0.9566 - accuracy: 0.5554 - val_loss: 0.9607 - val_accuracy: 0.5655
# Epoch 44/100
#  - 0s - loss: 0.9597 - accuracy: 0.5537 - val_loss: 0.9664 - val_accuracy: 0.5675
# Epoch 45/100
#  - 0s - loss: 0.9579 - accuracy: 0.5571 - val_loss: 0.9580 - val_accuracy: 0.5725
# Epoch 46/100
#  - 0s - loss: 0.9549 - accuracy: 0.5558 - val_loss: 0.9601 - val_accuracy: 0.5755
# Epoch 47/100
#  - 0s - loss: 0.9555 - accuracy: 0.5581 - val_loss: 0.9554 - val_accuracy: 0.5720
# Epoch 48/100
#  - 0s - loss: 0.9552 - accuracy: 0.5624 - val_loss: 0.9598 - val_accuracy: 0.5705
# Epoch 49/100
#  - 0s - loss: 0.9511 - accuracy: 0.5658 - val_loss: 0.9542 - val_accuracy: 0.5755
# Epoch 50/100
#  - 0s - loss: 0.9507 - accuracy: 0.5635 - val_loss: 0.9590 - val_accuracy: 0.5760
# Epoch 51/100
#  - 0s - loss: 0.9533 - accuracy: 0.5562 - val_loss: 0.9537 - val_accuracy: 0.5730
# Epoch 52/100
#  - 0s - loss: 0.9504 - accuracy: 0.5617 - val_loss: 0.9555 - val_accuracy: 0.5770
# Epoch 53/100
#  - 0s - loss: 0.9492 - accuracy: 0.5630 - val_loss: 0.9529 - val_accuracy: 0.5740
# Epoch 54/100
#  - 0s - loss: 0.9477 - accuracy: 0.5609 - val_loss: 0.9500 - val_accuracy: 0.5715
# Epoch 55/100
#  - 0s - loss: 0.9499 - accuracy: 0.5617 - val_loss: 0.9536 - val_accuracy: 0.5650
# Epoch 56/100
#  - 0s - loss: 0.9510 - accuracy: 0.5615 - val_loss: 0.9540 - val_accuracy: 0.5740
# Epoch 57/100
#  - 0s - loss: 0.9507 - accuracy: 0.5615 - val_loss: 0.9509 - val_accuracy: 0.5705
# Epoch 58/100
#  - 0s - loss: 0.9509 - accuracy: 0.5599 - val_loss: 0.9535 - val_accuracy: 0.5700
# Epoch 59/100
#  - 0s - loss: 0.9490 - accuracy: 0.5626 - val_loss: 0.9498 - val_accuracy: 0.5785
# Epoch 60/100
#  - 0s - loss: 0.9515 - accuracy: 0.5592 - val_loss: 0.9512 - val_accuracy: 0.5770
# Epoch 61/100
#  - 0s - loss: 0.9487 - accuracy: 0.5625 - val_loss: 0.9508 - val_accuracy: 0.5745
# Epoch 62/100
#  - 0s - loss: 0.9467 - accuracy: 0.5704 - val_loss: 0.9507 - val_accuracy: 0.5780
# Epoch 63/100
#  - 0s - loss: 0.9460 - accuracy: 0.5611 - val_loss: 0.9479 - val_accuracy: 0.5730
# Epoch 64/100
#  - 0s - loss: 0.9479 - accuracy: 0.5666 - val_loss: 0.9481 - val_accuracy: 0.5755
# Epoch 65/100
#  - 0s - loss: 0.9406 - accuracy: 0.5633 - val_loss: 0.9509 - val_accuracy: 0.5820
# Epoch 66/100
#  - 0s - loss: 0.9461 - accuracy: 0.5681 - val_loss: 0.9512 - val_accuracy: 0.5775
# Epoch 67/100
#  - 0s - loss: 0.9439 - accuracy: 0.5691 - val_loss: 0.9478 - val_accuracy: 0.5835
# Epoch 68/100
#  - 0s - loss: 0.9458 - accuracy: 0.5679 - val_loss: 0.9487 - val_accuracy: 0.5770
# Epoch 69/100
#  - 0s - loss: 0.9423 - accuracy: 0.5692 - val_loss: 0.9477 - val_accuracy: 0.5825
# Epoch 70/100
#  - 0s - loss: 0.9415 - accuracy: 0.5721 - val_loss: 0.9466 - val_accuracy: 0.5815
# Epoch 71/100
#  - 0s - loss: 0.9411 - accuracy: 0.5627 - val_loss: 0.9485 - val_accuracy: 0.5835
# Epoch 72/100
#  - 0s - loss: 0.9403 - accuracy: 0.5698 - val_loss: 0.9428 - val_accuracy: 0.5845
# Epoch 73/100
#  - 0s - loss: 0.9450 - accuracy: 0.5659 - val_loss: 0.9443 - val_accuracy: 0.5845
# Epoch 74/100
#  - 0s - loss: 0.9355 - accuracy: 0.5749 - val_loss: 0.9506 - val_accuracy: 0.5770
# Epoch 75/100
#  - 0s - loss: 0.9405 - accuracy: 0.5667 - val_loss: 0.9460 - val_accuracy: 0.5785
# Epoch 76/100
#  - 0s - loss: 0.9388 - accuracy: 0.5689 - val_loss: 0.9452 - val_accuracy: 0.5795
# Epoch 77/100
#  - 0s - loss: 0.9366 - accuracy: 0.5691 - val_loss: 0.9524 - val_accuracy: 0.5755
# Epoch 78/100
#  - 0s - loss: 0.9388 - accuracy: 0.5670 - val_loss: 0.9420 - val_accuracy: 0.5890
# Epoch 79/100
#  - 0s - loss: 0.9364 - accuracy: 0.5681 - val_loss: 0.9427 - val_accuracy: 0.5800
# Epoch 80/100
#  - 0s - loss: 0.9350 - accuracy: 0.5734 - val_loss: 0.9432 - val_accuracy: 0.5850
# Epoch 81/100
#  - 0s - loss: 0.9347 - accuracy: 0.5757 - val_loss: 0.9431 - val_accuracy: 0.5810
# Epoch 82/100
#  - 0s - loss: 0.9407 - accuracy: 0.5655 - val_loss: 0.9461 - val_accuracy: 0.5830
# Epoch 83/100
#  - 0s - loss: 0.9387 - accuracy: 0.5717 - val_loss: 0.9464 - val_accuracy: 0.5825
# Epoch 84/100
#  - 0s - loss: 0.9376 - accuracy: 0.5676 - val_loss: 0.9418 - val_accuracy: 0.5795
# Epoch 85/100
#  - 0s - loss: 0.9337 - accuracy: 0.5735 - val_loss: 0.9414 - val_accuracy: 0.5850
# Epoch 86/100
#  - 0s - loss: 0.9338 - accuracy: 0.5776 - val_loss: 0.9429 - val_accuracy: 0.5825
# Epoch 87/100
#  - 0s - loss: 0.9318 - accuracy: 0.5738 - val_loss: 0.9413 - val_accuracy: 0.5865
# Epoch 88/100
#  - 0s - loss: 0.9327 - accuracy: 0.5754 - val_loss: 0.9428 - val_accuracy: 0.5810
# Epoch 89/100
#  - 0s - loss: 0.9345 - accuracy: 0.5769 - val_loss: 0.9455 - val_accuracy: 0.5780
# Epoch 90/100
#  - 0s - loss: 0.9297 - accuracy: 0.5731 - val_loss: 0.9423 - val_accuracy: 0.5800
# Epoch 91/100
#  - 0s - loss: 0.9341 - accuracy: 0.5732 - val_loss: 0.9405 - val_accuracy: 0.5830
# Epoch 92/100
#  - 0s - loss: 0.9320 - accuracy: 0.5735 - val_loss: 0.9447 - val_accuracy: 0.5830
# Epoch 93/100
#  - 0s - loss: 0.9317 - accuracy: 0.5760 - val_loss: 0.9407 - val_accuracy: 0.5795
# Epoch 94/100
#  - 0s - loss: 0.9309 - accuracy: 0.5714 - val_loss: 0.9377 - val_accuracy: 0.5870
# Epoch 95/100
#  - 0s - loss: 0.9293 - accuracy: 0.5699 - val_loss: 0.9412 - val_accuracy: 0.5820
# Epoch 96/100
#  - 0s - loss: 0.9297 - accuracy: 0.5790 - val_loss: 0.9419 - val_accuracy: 0.5790
# Epoch 97/100
#  - 0s - loss: 0.9300 - accuracy: 0.5760 - val_loss: 0.9397 - val_accuracy: 0.5810
# Epoch 98/100
#  - 0s - loss: 0.9338 - accuracy: 0.5716 - val_loss: 0.9382 - val_accuracy: 0.5845
# Epoch 99/100
#  - 0s - loss: 0.9306 - accuracy: 0.5773 - val_loss: 0.9378 - val_accuracy: 0.5810
# Epoch 100/100
#  - 0s - loss: 0.9331 - accuracy: 0.5773 - val_loss: 0.9413 - val_accuracy: 0.5820

# %%
fig, ax = plt.subplots(1,7,figsize=(15,7))
ax_dict={}
ax_dict = {'reg_l1_1': ax[0], 'reg_l1_2': ax[1], 'reg_l1_3': ax[2], 'reg_l2_1': ax[3], 'reg_l2_2': ax[4],
          'reg_l2_3': ax[5], 'reg_l1_l2': ax[6]}

#Setting names
for key in ax_dict:
    ax_dict[key].set_title(key)
    
for model, reg in zip(model_list, ax_dict.keys()):    
    filters, biases = model.layers[-1].get_weights()
    ff = pd.DataFrame(filters)
    ax_dict[reg].imshow(ff)
    #sns.set(font_scale=1.4) # for label size
    #sns.heatmap(ff, annot=True, annot_kws={"size": 16}, cmap="GnBu",
          # linewidths=.5)

plt.show()

# %%
reg=['l1_1','l1_2','l1_3','l2_1','l2_2','l2_3','l1_l2']
# Accuracy
plt.figure(figsize=(10,8))
for fit ,test in zip(fits,reg):
    
    plt.plot(fit.history['accuracy'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_accuracy'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('accuracy', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='lower right', fontsize=fontsize)    
plt.show()

# Loss
plt.figure(figsize=(10,8))
for fit, test in zip(fits,reg):
    
    plt.plot(fit.history['loss'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_loss'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('loss', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='upper right', fontsize=fontsize)    
plt.show()
