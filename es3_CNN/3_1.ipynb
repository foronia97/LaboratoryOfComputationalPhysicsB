# %% [markdown]
# # Exercise 3: Convolutional Neural Networks
#
# Gruppo Stocafisici: Edoardo Antonaci, Angelica Foroni, Francesco Mazza, Leonardo Salicari.
#
# 1. Experiment with different architectures (which was left as an open point when “NCONV”
# variable was introduced), in particular try at least another version where only one
# convolutional layer is introduced instead of two, and where any number of dense layers may
# be used, with the global constraint of using a network with at most 600 trainable parameters.
# The filter length in the second convolutional layer may be shorter.
# Is the number of parameters scaling more quickly by adding Dense layers or Conv1D
# layers?
# Check which configuration works better by comparing the performances quantitatively.
# 2. Visualize the “confusion matrix” (look for similar examples in the material available or by
# googling)
# 3. With two convolutional layers, plot also the weights of the second layer and try to see if
# regularization may improve the performances by varying the parameter lambda of the L1 or
# of the L2 regularization; see lambda in eqs.(43) and (52) in the review. There is also a mixed
# version (l1_l2?) that can be tried. Is any value of lambda good? Is there any intermediate
# value where the performances of the network are better? Is there any improvement in the
# visualization and understanding of the weights in the filters? Note that the regularization we
# introduced acts on the w’s, not on the biases. One can also try the equivalent procedure for
# biases or for the output of the relu units (see Keras doc.), if there is any reason for
# suspecting that it may help. In our case, the logic was to let the weights of the filters go to
# zero if not needed, hence that kind of regularization was selected.
# 4. By reducing the signal-to-noise ratio, namely the amplitude of the external signal in the data
# (A) with respect to the step typical size of the jump process, check where the network starts
# to fail discriminating the categories.

# %% [markdown]
# We are going to use the dataset generated during the lecture.

# %%
import subprocess,csv
import random
import math
import matplotlib.pyplot as plt

# %%
random.seed(12345)

dx= lambda DX,bias :int ( (math.log(random.random() )*DX) *2*(random.randint(0,1)-0.5)+bias )

def pattern (i,z,a):
    return int(a*math.sin( (math.pi*i)/z) )

A= 300
Z=12

L=60
N=10000

DX=50
bias=5

y=[0]*N
x=[ [0] * L for i in range(N)]

for i in range(N):
    if i>0:
        x[i][0] = x[i-1][-1]
        
    for j in range(1,L):
        x[i][j] = x[i][j-1] +dx(DX,bias)
    
    y[i]= i%3
    if y[i]>0:
        j0 = random.randint(0,L-1-Z)
        sign =3-2*y[i]
        for j in range (Z):
            x[i][j0+j] += sign*pattern(j,Z,A)
            
str0 = f'DATA/ts_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.csv'

fname='x_'+str0

with open(fname,mode='w') as myfile :
    writer =csv.writer(myfile,delimiter=',')
    for i in range(N):
        writer.writerow(x[i])

# %% [markdown]
# ### Loading Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Version compatible with git folder
name = '_ts_L60_Z12_A12_DX50_bias5_N10000.csv'
xname = 'DATA/x' + name
yname = 'DATA/y' + name

# Other version
#name = '_ts_L60_Z12_A12_DX50_bias5_N10000.csv'
#xname = fname
#yname = 'y' + name

# Dataset
x = np.loadtxt(xname, delimiter=',', dtype=float)
N = x.shape[0]
L = x.shape[1]

# Labels
categ = np.loadtxt(yname, delimiter=',', dtype=int)
n_class = 3
y = np.zeros((N, n_class ))
for i in range(N):
    y[i][categ[i]] = 1.

# Removing avg and scaling data
x_avg = np.mean(x, axis=1).reshape(N,1) # average over sample (i.e. over rows)
x = (x - x_avg)/100 # one line to remove avg and scale; faster than a for loop
    
# Training and Validation
# Note, these are view, not copies
train_frac = .8
N_train = int(N*train_frac)
x_train = x[0:N_train,:]
y_train = y[0:N_train,:]
x_val = x[N_train:,:]
y_val = y[N_train:,:]

# Plotting some data
for k in range(3):
    plt.plot(x_train[k])
    
# Reshape for Keras
# Hence adding an extra dim wich correspond to the depth 
x_train = x_train.reshape(x_train.shape[0],L,1)
x_val = x_val.reshape(x_val.shape[0],L,1)

input_size = (L,1)

# %% [markdown]
# ## 1: CNN with different topologies

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.utils.layer_utils import count_params # for count number of parameters
from keras.losses import categorical_crossentropy
from keras import initializers, regularizers
from keras import optimizers

def create_model(NCONV=1, n_dense_layers=1, kernel_size_diff=1, summary=False):
    ''' 
    Creates a CNN with different topologies by changing NCONV 
    Returns the model and the number of trainable parameters
    
    n_dense_layers = number of dense layers in the CNN
    kernel_size_diff = (kernel_size first Conv layer) - (kernel_size second Conv layer)
    summary = print model.summary()
    
    NCONV == 1:
        From baiesi lecture
        Conv -> AvgPadding -> Conv -> Fattern -> Dense*(n_dense_layers) -> Dense (output)
    NCONV == 2: 
        Only one Conv layer
        Conv -> AvgPadding -> Fattern -> Dense*(n_dense_layers) -> Dense (output)
        
    '''
    if n_dense_layers < 1:
        raise('n_dense_layer must be int and >= 1')
        
    # Defining regulirizer
    reg = regularizers.l1(0.1)
    # Used to initialize kernel 
    init = initializers.RandomNormal(mean = 0,
                                       stddev = .05,
                                        seed = 12345) # reproducibility in training
    model = Sequential()

    if NCONV == 1:
        model.add( Conv1D(filters=5,
                          kernel_size = 11,                              
                          kernel_initializer = init,
                          kernel_regularizer = reg,
                          activation = 'relu',
                          input_shape = input_size
                         ) )
        model.add( AveragePooling1D(5) ) # max pooling windows' size
        model.add( Conv1D(filters=5, 
                          kernel_size = 11 - kernel_size_diff, 
                          activation = 'relu',) )
        model.add( Flatten() )
        for _ in range(n_dense_layers): # variable number of layers
            model.add( Dense(10, activation='relu') )
        model.add( Dropout(0.2) )
        
    elif NCONV == 2:
        model.add( Conv1D(filters=5,
                          kernel_size = 11,                              
                          kernel_initializer = init,
                          kernel_regularizer = reg,
                          activation = 'relu',
                          input_shape = input_size
                         ) )
        model.add( AveragePooling1D(5) ) # max pooling windows' size
        model.add( Flatten() )
        for _ in range(n_dense_layers): # variable number of layers
            model.add( Dense(10, activation='relu') )
        model.add( Dropout(0.2) )
    else:
        raise('NCONV must be an int: 1 or 2')
        
    # Output layer
    model.add(Dense(n_class, activation='softmax')) 
    
    # print model's details
    if summary: print(model.summary())
    # Number of trainable parameters
    trainable_count = count_params(model.trainable_weights)
    
    # Compiling model
    opt = optimizers.Nadam()
    model.compile( loss = categorical_crossentropy,
              optimizer = opt,
              metrics = ['accuracy'])
    
    return (model, trainable_count)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Training and test performance
#
#  Is the number of parameters scaling more quickly by adding Dense layers or Conv1D layers?

# %%
# Define dicts to test different topologies
# t1 == test 1
t1 = dict(NCONV = 1, n_dense_layers = 1, kernel_size_diff = 1)
t2 = dict(NCONV = 1, n_dense_layers = 2, kernel_size_diff = 1)
t3 = dict(NCONV = 1, n_dense_layers = 3, kernel_size_diff = 1)
t4 = dict(NCONV = 2, n_dense_layers = 1, kernel_size_diff = 1)
t5 = dict(NCONV = 2, n_dense_layers = 2, kernel_size_diff = 1)
t6 = dict(NCONV = 1, n_dense_layers = 1, kernel_size_diff = 4)

# Array with tests
tests = [t1,t2,t3,t4,t5,t6]
# Array with names for plotting porpuses
tests_plot = ['t1','t2','t3','t4','t5','t6']
# Array to save # of parameters
params = [0] * len(tests)

for idx,t in enumerate(tests):
    _, params[idx] = create_model(**t, summary=False) # **t is the syntax to 'unpack' values from dict
    
# Visualising number of parameters
plt.close()
plt.plot(tests_plot, params, '*')
plt.axhline(y=600, color='red') # line of 600 parameters
plt.xlabel('Tests')
plt.ylabel('# of trainable parameters')
# Out:
# Text(0, 0.5, '# of trainable parameters')

# %% [markdown]
# #### Comment
# It's seems like that removing a `Conv1D` layer the number of trainable parameters grows. Looking at the summary of the models, this apparent contradiction seems to be solve by the fact that in the case of 2 convolutional layers the `output size` of the layer's output is smaller compared to the model with only one convolutional layer.
#
# Than, the fully connected layers (the `Dense` one) han a number of trainable parameters related to the number of weights and biases which grows quickly with the `output size` of the previous layer. Hence, the one-convolutional-layer model has more parameters due to its bigger output given to the fully connected layer.
#
# For more info, use the option `summary=True` in the `create_model()` function's call.
#
# ### Performance comparison
# It'll be trained models relative to configurations `t2`, `t4` and `t6`

# %%
model2, _ = create_model(**t2)
model4, _ = create_model(**t4)
model6, _ = create_model(**t6)

# Training
batch_size = 250
epochs = 125

fit2 = model2.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
fit4 = model4.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
fit6 = model6.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=(x_val,y_val),
                verbose = 2,
                shuffle = True)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/125
#  - 1s - loss: 1.2367 - accuracy: 0.3983 - val_loss: 1.1476 - val_accuracy: 0.4745
# Epoch 2/125
#  - 0s - loss: 1.1097 - accuracy: 0.4456 - val_loss: 1.0751 - val_accuracy: 0.5265
# Epoch 3/125
#  - 0s - loss: 1.0309 - accuracy: 0.5199 - val_loss: 0.9669 - val_accuracy: 0.5680
# Epoch 4/125
#  - 0s - loss: 0.9500 - accuracy: 0.5591 - val_loss: 0.9337 - val_accuracy: 0.5730
# Epoch 5/125
#  - 0s - loss: 0.9059 - accuracy: 0.5822 - val_loss: 0.8608 - val_accuracy: 0.6080
# Epoch 6/125
#  - 0s - loss: 0.8704 - accuracy: 0.6060 - val_loss: 0.8328 - val_accuracy: 0.6245
# Epoch 7/125
#  - 0s - loss: 0.8351 - accuracy: 0.6331 - val_loss: 0.8036 - val_accuracy: 0.6520
# Epoch 8/125
#  - 0s - loss: 0.8161 - accuracy: 0.6470 - val_loss: 0.7946 - val_accuracy: 0.6725
# Epoch 9/125
#  - 0s - loss: 0.7942 - accuracy: 0.6716 - val_loss: 0.8028 - val_accuracy: 0.6535
# Epoch 10/125
#  - 0s - loss: 0.7776 - accuracy: 0.6904 - val_loss: 0.7418 - val_accuracy: 0.7015
# Epoch 11/125
#  - 0s - loss: 0.7461 - accuracy: 0.7161 - val_loss: 0.7138 - val_accuracy: 0.7425
# Epoch 12/125
#  - 0s - loss: 0.7270 - accuracy: 0.7269 - val_loss: 0.6675 - val_accuracy: 0.7810
# Epoch 13/125
#  - 0s - loss: 0.6791 - accuracy: 0.7580 - val_loss: 0.6500 - val_accuracy: 0.7825
# Epoch 14/125
#  - 0s - loss: 0.6683 - accuracy: 0.7554 - val_loss: 0.6552 - val_accuracy: 0.7815
# Epoch 15/125
#  - 0s - loss: 0.6413 - accuracy: 0.7714 - val_loss: 0.5700 - val_accuracy: 0.8255
# Epoch 16/125
#  - 0s - loss: 0.6159 - accuracy: 0.7865 - val_loss: 0.5588 - val_accuracy: 0.8235
# Epoch 17/125
#  - 0s - loss: 0.5971 - accuracy: 0.7951 - val_loss: 0.5337 - val_accuracy: 0.8380
# Epoch 18/125
#  - 0s - loss: 0.5675 - accuracy: 0.8200 - val_loss: 0.5374 - val_accuracy: 0.8265
# Epoch 19/125
#  - 0s - loss: 0.5795 - accuracy: 0.8111 - val_loss: 0.5194 - val_accuracy: 0.8400
# Epoch 20/125
#  - 0s - loss: 0.5406 - accuracy: 0.8265 - val_loss: 0.4850 - val_accuracy: 0.8530
# Epoch 21/125
#  - 0s - loss: 0.5327 - accuracy: 0.8321 - val_loss: 0.4759 - val_accuracy: 0.8575
# Epoch 22/125
#  - 0s - loss: 0.5420 - accuracy: 0.8300 - val_loss: 0.4879 - val_accuracy: 0.8435
# Epoch 23/125
#  - 0s - loss: 0.5262 - accuracy: 0.8369 - val_loss: 0.4707 - val_accuracy: 0.8580
# Epoch 24/125
#  - 0s - loss: 0.5226 - accuracy: 0.8379 - val_loss: 0.4643 - val_accuracy: 0.8595
# Epoch 25/125
#  - 0s - loss: 0.5054 - accuracy: 0.8385 - val_loss: 0.4679 - val_accuracy: 0.8555
# Epoch 26/125
#  - 0s - loss: 0.4987 - accuracy: 0.8479 - val_loss: 0.4708 - val_accuracy: 0.8490
# Epoch 27/125
#  - 0s - loss: 0.5103 - accuracy: 0.8401 - val_loss: 0.4480 - val_accuracy: 0.8690
# Epoch 28/125
#  - 0s - loss: 0.4896 - accuracy: 0.8450 - val_loss: 0.4605 - val_accuracy: 0.8575
# Epoch 29/125
#  - 0s - loss: 0.4952 - accuracy: 0.8444 - val_loss: 0.4601 - val_accuracy: 0.8585
# Epoch 30/125
#  - 0s - loss: 0.4924 - accuracy: 0.8478 - val_loss: 0.4429 - val_accuracy: 0.8655
# Epoch 31/125
#  - 0s - loss: 0.4874 - accuracy: 0.8526 - val_loss: 0.4455 - val_accuracy: 0.8685
# Epoch 32/125
#  - 0s - loss: 0.4711 - accuracy: 0.8576 - val_loss: 0.4558 - val_accuracy: 0.8620
# Epoch 33/125
#  - 0s - loss: 0.4759 - accuracy: 0.8581 - val_loss: 0.4297 - val_accuracy: 0.8720
# Epoch 34/125
#  - 0s - loss: 0.4663 - accuracy: 0.8595 - val_loss: 0.4357 - val_accuracy: 0.8705
# Epoch 35/125
#  - 0s - loss: 0.4689 - accuracy: 0.8620 - val_loss: 0.4528 - val_accuracy: 0.8580
# Epoch 36/125
#  - 0s - loss: 0.4668 - accuracy: 0.8619 - val_loss: 0.4217 - val_accuracy: 0.8745
# Epoch 37/125
#  - 0s - loss: 0.4878 - accuracy: 0.8510 - val_loss: 0.4327 - val_accuracy: 0.8745
# Epoch 38/125
#  - 0s - loss: 0.4548 - accuracy: 0.8640 - val_loss: 0.4632 - val_accuracy: 0.8590
# Epoch 39/125
#  - 0s - loss: 0.4841 - accuracy: 0.8533 - val_loss: 0.4267 - val_accuracy: 0.8765
# Epoch 40/125
#  - 0s - loss: 0.4566 - accuracy: 0.8629 - val_loss: 0.4203 - val_accuracy: 0.8755
# Epoch 41/125
#  - 0s - loss: 0.4482 - accuracy: 0.8677 - val_loss: 0.4207 - val_accuracy: 0.8725
# Epoch 42/125
#  - 0s - loss: 0.4564 - accuracy: 0.8626 - val_loss: 0.4216 - val_accuracy: 0.8765
# Epoch 43/125
#  - 0s - loss: 0.4551 - accuracy: 0.8660 - val_loss: 0.4382 - val_accuracy: 0.8695
# Epoch 44/125
#  - 0s - loss: 0.4779 - accuracy: 0.8568 - val_loss: 0.4191 - val_accuracy: 0.8750
# Epoch 45/125
#  - 0s - loss: 0.4472 - accuracy: 0.8677 - val_loss: 0.4176 - val_accuracy: 0.8730
# Epoch 46/125
#  - 0s - loss: 0.4462 - accuracy: 0.8666 - val_loss: 0.4315 - val_accuracy: 0.8675
# Epoch 47/125
#  - 0s - loss: 0.4437 - accuracy: 0.8684 - val_loss: 0.4278 - val_accuracy: 0.8715
# Epoch 48/125
#  - 0s - loss: 0.4912 - accuracy: 0.8524 - val_loss: 0.4192 - val_accuracy: 0.8735
# Epoch 49/125
#  - 0s - loss: 0.4537 - accuracy: 0.8702 - val_loss: 0.4303 - val_accuracy: 0.8700
# Epoch 50/125
#  - 0s - loss: 0.4415 - accuracy: 0.8708 - val_loss: 0.4217 - val_accuracy: 0.8725
# Epoch 51/125
#  - 0s - loss: 0.4381 - accuracy: 0.8681 - val_loss: 0.4205 - val_accuracy: 0.8705
# Epoch 52/125
#  - 0s - loss: 0.4808 - accuracy: 0.8579 - val_loss: 0.4128 - val_accuracy: 0.8770
# Epoch 53/125
#  - 0s - loss: 0.4556 - accuracy: 0.8601 - val_loss: 0.4151 - val_accuracy: 0.8765
# Epoch 54/125
#  - 0s - loss: 0.4595 - accuracy: 0.8604 - val_loss: 0.4105 - val_accuracy: 0.8795
# Epoch 55/125
#  - 0s - loss: 0.4324 - accuracy: 0.8721 - val_loss: 0.4199 - val_accuracy: 0.8755
# Epoch 56/125
#  - 0s - loss: 0.4353 - accuracy: 0.8710 - val_loss: 0.4116 - val_accuracy: 0.8740
# Epoch 57/125
#  - 0s - loss: 0.4309 - accuracy: 0.8717 - val_loss: 0.4089 - val_accuracy: 0.8770
# Epoch 58/125
#  - 0s - loss: 0.4324 - accuracy: 0.8737 - val_loss: 0.4072 - val_accuracy: 0.8785
# Epoch 59/125
#  - 0s - loss: 0.4377 - accuracy: 0.8725 - val_loss: 0.4136 - val_accuracy: 0.8770
# Epoch 60/125
#  - 0s - loss: 0.4510 - accuracy: 0.8676 - val_loss: 0.4243 - val_accuracy: 0.8740
# Epoch 61/125
#  - 0s - loss: 0.4368 - accuracy: 0.8698 - val_loss: 0.4059 - val_accuracy: 0.8770
# Epoch 62/125
#  - 0s - loss: 0.4369 - accuracy: 0.8681 - val_loss: 0.5490 - val_accuracy: 0.8255
# Epoch 63/125
#  - 0s - loss: 0.4361 - accuracy: 0.8699 - val_loss: 0.4059 - val_accuracy: 0.8775
# Epoch 64/125
#  - 0s - loss: 0.4288 - accuracy: 0.8750 - val_loss: 0.4069 - val_accuracy: 0.8785
# Epoch 65/125
#  - 0s - loss: 0.4337 - accuracy: 0.8692 - val_loss: 0.4677 - val_accuracy: 0.8570
# Epoch 66/125
#  - 0s - loss: 0.4348 - accuracy: 0.8683 - val_loss: 0.4236 - val_accuracy: 0.8740
# Epoch 67/125
#  - 0s - loss: 0.4203 - accuracy: 0.8730 - val_loss: 0.4116 - val_accuracy: 0.8755
# Epoch 68/125
#  - 0s - loss: 0.4544 - accuracy: 0.8625 - val_loss: 0.4118 - val_accuracy: 0.8725
# Epoch 69/125
#  - 0s - loss: 0.4214 - accuracy: 0.8745 - val_loss: 0.4074 - val_accuracy: 0.8745
# Epoch 70/125
#  - 0s - loss: 0.4297 - accuracy: 0.8706 - val_loss: 0.4052 - val_accuracy: 0.8810
# Epoch 71/125
#  - 0s - loss: 0.4208 - accuracy: 0.8763 - val_loss: 0.4166 - val_accuracy: 0.8745
# Epoch 72/125
#  - 0s - loss: 0.4231 - accuracy: 0.8720 - val_loss: 0.4017 - val_accuracy: 0.8790
# Epoch 73/125
#  - 0s - loss: 0.4320 - accuracy: 0.8705 - val_loss: 0.4062 - val_accuracy: 0.8800
# Epoch 74/125
#  - 0s - loss: 0.4275 - accuracy: 0.8734 - val_loss: 0.4352 - val_accuracy: 0.8630
# Epoch 75/125
#  - 0s - loss: 0.5828 - accuracy: 0.8303 - val_loss: 0.4399 - val_accuracy: 0.8670
# Epoch 76/125
#  - 0s - loss: 0.4314 - accuracy: 0.8733 - val_loss: 0.4031 - val_accuracy: 0.8785
# Epoch 77/125
#  - 0s - loss: 0.4234 - accuracy: 0.8766 - val_loss: 0.4042 - val_accuracy: 0.8785
# Epoch 78/125
#  - 0s - loss: 0.4217 - accuracy: 0.8729 - val_loss: 0.4091 - val_accuracy: 0.8755
# Epoch 79/125
#  - 0s - loss: 0.4302 - accuracy: 0.8686 - val_loss: 0.4363 - val_accuracy: 0.8640
# Epoch 80/125
#  - 0s - loss: 0.4353 - accuracy: 0.8686 - val_loss: 0.3997 - val_accuracy: 0.8795
# Epoch 81/125
#  - 0s - loss: 0.4143 - accuracy: 0.8758 - val_loss: 0.4004 - val_accuracy: 0.8805
# Epoch 82/125
#  - 0s - loss: 0.4272 - accuracy: 0.8709 - val_loss: 0.4028 - val_accuracy: 0.8775
# Epoch 83/125
#  - 0s - loss: 0.4237 - accuracy: 0.8727 - val_loss: 0.4093 - val_accuracy: 0.8730
# Epoch 84/125
#  - 0s - loss: 0.4276 - accuracy: 0.8733 - val_loss: 0.3990 - val_accuracy: 0.8800
# Epoch 85/125
#  - 0s - loss: 0.4306 - accuracy: 0.8701 - val_loss: 0.4276 - val_accuracy: 0.8715
# Epoch 86/125
#  - 0s - loss: 0.4182 - accuracy: 0.8739 - val_loss: 0.4056 - val_accuracy: 0.8755
# Epoch 87/125
#  - 0s - loss: 0.4188 - accuracy: 0.8737 - val_loss: 0.3991 - val_accuracy: 0.8815
# Epoch 88/125
#  - 0s - loss: 0.4198 - accuracy: 0.8731 - val_loss: 0.4163 - val_accuracy: 0.8775
# Epoch 89/125
#  - 0s - loss: 0.4386 - accuracy: 0.8676 - val_loss: 0.4234 - val_accuracy: 0.8695
# Epoch 90/125
#  - 0s - loss: 0.4125 - accuracy: 0.8755 - val_loss: 0.4204 - val_accuracy: 0.8700
# Epoch 91/125
#  - 0s - loss: 0.4203 - accuracy: 0.8736 - val_loss: 0.3972 - val_accuracy: 0.8825
# Epoch 92/125
#  - 0s - loss: 0.4248 - accuracy: 0.8699 - val_loss: 0.4501 - val_accuracy: 0.8640
# Epoch 93/125
#  - 0s - loss: 0.4109 - accuracy: 0.8777 - val_loss: 0.3973 - val_accuracy: 0.8750
# Epoch 94/125
#  - 0s - loss: 0.4203 - accuracy: 0.8734 - val_loss: 0.6530 - val_accuracy: 0.7865
# Epoch 95/125
#  - 0s - loss: 0.4311 - accuracy: 0.8662 - val_loss: 0.4250 - val_accuracy: 0.8670
# Epoch 96/125
#  - 0s - loss: 0.4233 - accuracy: 0.8702 - val_loss: 0.4037 - val_accuracy: 0.8730
# Epoch 97/125
#  - 0s - loss: 0.4328 - accuracy: 0.8665 - val_loss: 0.3988 - val_accuracy: 0.8785
# Epoch 98/125
#  - 0s - loss: 0.4135 - accuracy: 0.8751 - val_loss: 0.4235 - val_accuracy: 0.8690
# Epoch 99/125
#  - 0s - loss: 0.4674 - accuracy: 0.8572 - val_loss: 0.4074 - val_accuracy: 0.8745
# Epoch 100/125
#  - 0s - loss: 0.4149 - accuracy: 0.8721 - val_loss: 0.3988 - val_accuracy: 0.8780
# Epoch 101/125
#  - 0s - loss: 0.4108 - accuracy: 0.8752 - val_loss: 0.4317 - val_accuracy: 0.8670
# Epoch 102/125
#  - 0s - loss: 0.4338 - accuracy: 0.8644 - val_loss: 0.3944 - val_accuracy: 0.8795
# Epoch 103/125
#  - 0s - loss: 0.4163 - accuracy: 0.8720 - val_loss: 0.3978 - val_accuracy: 0.8795
# Epoch 104/125
#  - 0s - loss: 0.4169 - accuracy: 0.8712 - val_loss: 0.3955 - val_accuracy: 0.8755
# Epoch 105/125
#  - 0s - loss: 0.4117 - accuracy: 0.8739 - val_loss: 0.3951 - val_accuracy: 0.8785
# Epoch 106/125
#  - 0s - loss: 0.4145 - accuracy: 0.8724 - val_loss: 0.3926 - val_accuracy: 0.8765
# Epoch 107/125
#  - 0s - loss: 0.4159 - accuracy: 0.8731 - val_loss: 0.4007 - val_accuracy: 0.8780
# Epoch 108/125
#  - 0s - loss: 0.4225 - accuracy: 0.8737 - val_loss: 0.3950 - val_accuracy: 0.8825
# Epoch 109/125
#  - 0s - loss: 0.4121 - accuracy: 0.8723 - val_loss: 0.5453 - val_accuracy: 0.8215
# Epoch 110/125
#  - 0s - loss: 0.4301 - accuracy: 0.8671 - val_loss: 0.3998 - val_accuracy: 0.8800
# Epoch 111/125
#  - 0s - loss: 0.4045 - accuracy: 0.8705 - val_loss: 0.4167 - val_accuracy: 0.8725
# Epoch 112/125
#  - 0s - loss: 0.4102 - accuracy: 0.8767 - val_loss: 0.3895 - val_accuracy: 0.8800
# Epoch 113/125
#  - 0s - loss: 0.4103 - accuracy: 0.8730 - val_loss: 0.4050 - val_accuracy: 0.8790
# Epoch 114/125
#  - 0s - loss: 0.4239 - accuracy: 0.8684 - val_loss: 0.4454 - val_accuracy: 0.8640
# Epoch 115/125
#  - 0s - loss: 0.4259 - accuracy: 0.8661 - val_loss: 0.4319 - val_accuracy: 0.8705
# Epoch 116/125
#  - 0s - loss: 0.4297 - accuracy: 0.8700 - val_loss: 0.3915 - val_accuracy: 0.8825
# Epoch 117/125
#  - 0s - loss: 0.4222 - accuracy: 0.8709 - val_loss: 0.3921 - val_accuracy: 0.8815
# Epoch 118/125
#  - 0s - loss: 0.4081 - accuracy: 0.8719 - val_loss: 0.4058 - val_accuracy: 0.8760
# Epoch 119/125
#  - 0s - loss: 0.4201 - accuracy: 0.8696 - val_loss: 0.5434 - val_accuracy: 0.8230
# Epoch 120/125
#  - 0s - loss: 0.4051 - accuracy: 0.8733 - val_loss: 0.4093 - val_accuracy: 0.8770
# Epoch 121/125
#  - 0s - loss: 0.4094 - accuracy: 0.8723 - val_loss: 0.4012 - val_accuracy: 0.8735
# Epoch 122/125
#  - 0s - loss: 0.4257 - accuracy: 0.8659 - val_loss: 0.3965 - val_accuracy: 0.8765
# Epoch 123/125
#  - 0s - loss: 0.4201 - accuracy: 0.8675 - val_loss: 0.4101 - val_accuracy: 0.8730
# Epoch 124/125
#  - 0s - loss: 0.4152 - accuracy: 0.8691 - val_loss: 0.3958 - val_accuracy: 0.8740
# Epoch 125/125
#  - 0s - loss: 0.4111 - accuracy: 0.8746 - val_loss: 0.4009 - val_accuracy: 0.8800
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/125
#  - 1s - loss: 1.2150 - accuracy: 0.3543 - val_loss: 1.1318 - val_accuracy: 0.3640
# Epoch 2/125
#  - 0s - loss: 1.1148 - accuracy: 0.3761 - val_loss: 1.1059 - val_accuracy: 0.3805
# Epoch 3/125
#  - 0s - loss: 1.1035 - accuracy: 0.3949 - val_loss: 1.0994 - val_accuracy: 0.4275
# Epoch 4/125
#  - 0s - loss: 1.0938 - accuracy: 0.4375 - val_loss: 1.0861 - val_accuracy: 0.4735
# Epoch 5/125
#  - 0s - loss: 1.0743 - accuracy: 0.4854 - val_loss: 1.0579 - val_accuracy: 0.5030
# Epoch 6/125
#  - 0s - loss: 1.0441 - accuracy: 0.5036 - val_loss: 1.0280 - val_accuracy: 0.5320
# Epoch 7/125
#  - 0s - loss: 1.0081 - accuracy: 0.5460 - val_loss: 0.9868 - val_accuracy: 0.5630
# Epoch 8/125
#  - 0s - loss: 0.9842 - accuracy: 0.5589 - val_loss: 0.9532 - val_accuracy: 0.5905
# Epoch 9/125
#  - 0s - loss: 0.9579 - accuracy: 0.5774 - val_loss: 0.9445 - val_accuracy: 0.5920
# Epoch 10/125
#  - 0s - loss: 0.9379 - accuracy: 0.5904 - val_loss: 0.9054 - val_accuracy: 0.6190
# Epoch 11/125
#  - 0s - loss: 0.9114 - accuracy: 0.6120 - val_loss: 0.8882 - val_accuracy: 0.6390
# Epoch 12/125
#  - 0s - loss: 0.9092 - accuracy: 0.6158 - val_loss: 0.8756 - val_accuracy: 0.6560
# Epoch 13/125
#  - 0s - loss: 0.8897 - accuracy: 0.6241 - val_loss: 0.8711 - val_accuracy: 0.6550
# Epoch 14/125
#  - 0s - loss: 0.8811 - accuracy: 0.6354 - val_loss: 0.8770 - val_accuracy: 0.6575
# Epoch 15/125
#  - 0s - loss: 0.8714 - accuracy: 0.6410 - val_loss: 0.8537 - val_accuracy: 0.6655
# Epoch 16/125
#  - 0s - loss: 0.8600 - accuracy: 0.6545 - val_loss: 0.8374 - val_accuracy: 0.6815
# Epoch 17/125
#  - 0s - loss: 0.8479 - accuracy: 0.6607 - val_loss: 0.8241 - val_accuracy: 0.6925
# Epoch 18/125
#  - 0s - loss: 0.8405 - accuracy: 0.6676 - val_loss: 0.8164 - val_accuracy: 0.6955
# Epoch 19/125
#  - 0s - loss: 0.8330 - accuracy: 0.6727 - val_loss: 0.8059 - val_accuracy: 0.7045
# Epoch 20/125
#  - 0s - loss: 0.8199 - accuracy: 0.6793 - val_loss: 0.8040 - val_accuracy: 0.7090
# Epoch 21/125
#  - 0s - loss: 0.8117 - accuracy: 0.6852 - val_loss: 0.8031 - val_accuracy: 0.7000
# Epoch 22/125
#  - 0s - loss: 0.8047 - accuracy: 0.6896 - val_loss: 0.7939 - val_accuracy: 0.7210
# Epoch 23/125
#  - 0s - loss: 0.7953 - accuracy: 0.7003 - val_loss: 0.7748 - val_accuracy: 0.7205
# Epoch 24/125
#  - 0s - loss: 0.7827 - accuracy: 0.7020 - val_loss: 0.7749 - val_accuracy: 0.7425
# Epoch 25/125
#  - 0s - loss: 0.7742 - accuracy: 0.7164 - val_loss: 0.7534 - val_accuracy: 0.7380
# Epoch 26/125
#  - 0s - loss: 0.7756 - accuracy: 0.7145 - val_loss: 0.7690 - val_accuracy: 0.7360
# Epoch 27/125
#  - 0s - loss: 0.7585 - accuracy: 0.7249 - val_loss: 0.7362 - val_accuracy: 0.7460
# Epoch 28/125
#  - 0s - loss: 0.7636 - accuracy: 0.7224 - val_loss: 0.7408 - val_accuracy: 0.7565
# Epoch 29/125
#  - 0s - loss: 0.7526 - accuracy: 0.7308 - val_loss: 0.7208 - val_accuracy: 0.7600
# Epoch 30/125
#  - 0s - loss: 0.7427 - accuracy: 0.7414 - val_loss: 0.7228 - val_accuracy: 0.7670
# Epoch 31/125
#  - 0s - loss: 0.7359 - accuracy: 0.7423 - val_loss: 0.7327 - val_accuracy: 0.7470
# Epoch 32/125
#  - 0s - loss: 0.7216 - accuracy: 0.7539 - val_loss: 0.6892 - val_accuracy: 0.7750
# Epoch 33/125
#  - 0s - loss: 0.7176 - accuracy: 0.7552 - val_loss: 0.6760 - val_accuracy: 0.7870
# Epoch 34/125
#  - 0s - loss: 0.7039 - accuracy: 0.7607 - val_loss: 0.6744 - val_accuracy: 0.7835
# Epoch 35/125
#  - 0s - loss: 0.6934 - accuracy: 0.7665 - val_loss: 0.6564 - val_accuracy: 0.7995
# Epoch 36/125
#  - 0s - loss: 0.6847 - accuracy: 0.7716 - val_loss: 0.6560 - val_accuracy: 0.7965
# Epoch 37/125
#  - 0s - loss: 0.6822 - accuracy: 0.7730 - val_loss: 0.6647 - val_accuracy: 0.7835
# Epoch 38/125
#  - 0s - loss: 0.6766 - accuracy: 0.7760 - val_loss: 0.6348 - val_accuracy: 0.7980
# Epoch 39/125
#  - 0s - loss: 0.6662 - accuracy: 0.7796 - val_loss: 0.6346 - val_accuracy: 0.8060
# Epoch 40/125
#  - 0s - loss: 0.6594 - accuracy: 0.7850 - val_loss: 0.6627 - val_accuracy: 0.7925
# Epoch 41/125
#  - 0s - loss: 0.6741 - accuracy: 0.7776 - val_loss: 0.6513 - val_accuracy: 0.7980
# Epoch 42/125
#  - 0s - loss: 0.6480 - accuracy: 0.7901 - val_loss: 0.6213 - val_accuracy: 0.8140
# Epoch 43/125
#  - 0s - loss: 0.6427 - accuracy: 0.7950 - val_loss: 0.6099 - val_accuracy: 0.8095
# Epoch 44/125
#  - 0s - loss: 0.6304 - accuracy: 0.7996 - val_loss: 0.5949 - val_accuracy: 0.8255
# Epoch 45/125
#  - 0s - loss: 0.6238 - accuracy: 0.8074 - val_loss: 0.5885 - val_accuracy: 0.8215
# Epoch 46/125
#  - 0s - loss: 0.6100 - accuracy: 0.8110 - val_loss: 0.5715 - val_accuracy: 0.8380
# Epoch 47/125
#  - 0s - loss: 0.6033 - accuracy: 0.8161 - val_loss: 0.5634 - val_accuracy: 0.8365
# Epoch 48/125
#  - 0s - loss: 0.6076 - accuracy: 0.8117 - val_loss: 0.5642 - val_accuracy: 0.8370
# Epoch 49/125
#  - 0s - loss: 0.5984 - accuracy: 0.8167 - val_loss: 0.5672 - val_accuracy: 0.8335
# Epoch 50/125
#  - 0s - loss: 0.5884 - accuracy: 0.8194 - val_loss: 0.5503 - val_accuracy: 0.8515
# Epoch 51/125
#  - 0s - loss: 0.5825 - accuracy: 0.8242 - val_loss: 0.5434 - val_accuracy: 0.8530
# Epoch 52/125
#  - 0s - loss: 0.5787 - accuracy: 0.8251 - val_loss: 0.5287 - val_accuracy: 0.8580
# Epoch 53/125
#  - 0s - loss: 0.5668 - accuracy: 0.8270 - val_loss: 0.5420 - val_accuracy: 0.8420
# Epoch 54/125
#  - 0s - loss: 0.5620 - accuracy: 0.8288 - val_loss: 0.5309 - val_accuracy: 0.8475
# Epoch 55/125
#  - 0s - loss: 0.5615 - accuracy: 0.8294 - val_loss: 0.5368 - val_accuracy: 0.8440
# Epoch 56/125
#  - 0s - loss: 0.5594 - accuracy: 0.8307 - val_loss: 0.5196 - val_accuracy: 0.8505
# Epoch 57/125
#  - 0s - loss: 0.5467 - accuracy: 0.8354 - val_loss: 0.5262 - val_accuracy: 0.8520
# Epoch 58/125
#  - 0s - loss: 0.5488 - accuracy: 0.8330 - val_loss: 0.5102 - val_accuracy: 0.8645
# Epoch 59/125
#  - 0s - loss: 0.5394 - accuracy: 0.8371 - val_loss: 0.5157 - val_accuracy: 0.8455
# Epoch 60/125
#  - 0s - loss: 0.5372 - accuracy: 0.8411 - val_loss: 0.4992 - val_accuracy: 0.8590
# Epoch 61/125
#  - 0s - loss: 0.5365 - accuracy: 0.8379 - val_loss: 0.4982 - val_accuracy: 0.8565
# Epoch 62/125
#  - 0s - loss: 0.5341 - accuracy: 0.8376 - val_loss: 0.4974 - val_accuracy: 0.8590
# Epoch 63/125
#  - 0s - loss: 0.5327 - accuracy: 0.8366 - val_loss: 0.5058 - val_accuracy: 0.8570
# Epoch 64/125
#  - 0s - loss: 0.5243 - accuracy: 0.8460 - val_loss: 0.4795 - val_accuracy: 0.8670
# Epoch 65/125
#  - 0s - loss: 0.5199 - accuracy: 0.8491 - val_loss: 0.4909 - val_accuracy: 0.8625
# Epoch 66/125
#  - 0s - loss: 0.5281 - accuracy: 0.8419 - val_loss: 0.4747 - val_accuracy: 0.8660
# Epoch 67/125
#  - 0s - loss: 0.5146 - accuracy: 0.8508 - val_loss: 0.4809 - val_accuracy: 0.8605
# Epoch 68/125
#  - 0s - loss: 0.5206 - accuracy: 0.8436 - val_loss: 0.4728 - val_accuracy: 0.8665
# Epoch 69/125
#  - 0s - loss: 0.5131 - accuracy: 0.8510 - val_loss: 0.4950 - val_accuracy: 0.8580
# Epoch 70/125
#  - 0s - loss: 0.5162 - accuracy: 0.8465 - val_loss: 0.4743 - val_accuracy: 0.8675
# Epoch 71/125
#  - 0s - loss: 0.5142 - accuracy: 0.8447 - val_loss: 0.5101 - val_accuracy: 0.8460
# Epoch 72/125
#  - 0s - loss: 0.5104 - accuracy: 0.8478 - val_loss: 0.5098 - val_accuracy: 0.8480
# Epoch 73/125
#  - 0s - loss: 0.5071 - accuracy: 0.8539 - val_loss: 0.4654 - val_accuracy: 0.8690
# Epoch 74/125
#  - 0s - loss: 0.5048 - accuracy: 0.8525 - val_loss: 0.4729 - val_accuracy: 0.8695
# Epoch 75/125
#  - 0s - loss: 0.4992 - accuracy: 0.8547 - val_loss: 0.4632 - val_accuracy: 0.8685
# Epoch 76/125
#  - 0s - loss: 0.5047 - accuracy: 0.8512 - val_loss: 0.4747 - val_accuracy: 0.8650
# Epoch 77/125
#  - 0s - loss: 0.4995 - accuracy: 0.8550 - val_loss: 0.4927 - val_accuracy: 0.8515
# Epoch 78/125
#  - 0s - loss: 0.4940 - accuracy: 0.8534 - val_loss: 0.5214 - val_accuracy: 0.8400
# Epoch 79/125
#  - 0s - loss: 0.5013 - accuracy: 0.8490 - val_loss: 0.4603 - val_accuracy: 0.8690
# Epoch 80/125
#  - 0s - loss: 0.4993 - accuracy: 0.8543 - val_loss: 0.4756 - val_accuracy: 0.8640
# Epoch 81/125
#  - 0s - loss: 0.4972 - accuracy: 0.8555 - val_loss: 0.4589 - val_accuracy: 0.8695
# Epoch 82/125
#  - 0s - loss: 0.4945 - accuracy: 0.8553 - val_loss: 0.4530 - val_accuracy: 0.8730
# Epoch 83/125
#  - 0s - loss: 0.4940 - accuracy: 0.8555 - val_loss: 0.4644 - val_accuracy: 0.8620
# Epoch 84/125
#  - 0s - loss: 0.4868 - accuracy: 0.8556 - val_loss: 0.4740 - val_accuracy: 0.8570
# Epoch 85/125
#  - 0s - loss: 0.4801 - accuracy: 0.8589 - val_loss: 0.4496 - val_accuracy: 0.8730
# Epoch 86/125
#  - 0s - loss: 0.4829 - accuracy: 0.8571 - val_loss: 0.4576 - val_accuracy: 0.8660
# Epoch 87/125
#  - 0s - loss: 0.4987 - accuracy: 0.8526 - val_loss: 0.4716 - val_accuracy: 0.8575
# Epoch 88/125
#  - 0s - loss: 0.4797 - accuracy: 0.8612 - val_loss: 0.4546 - val_accuracy: 0.8630
# Epoch 89/125
#  - 0s - loss: 0.4859 - accuracy: 0.8602 - val_loss: 0.4487 - val_accuracy: 0.8725
# Epoch 90/125
#  - 0s - loss: 0.4871 - accuracy: 0.8549 - val_loss: 0.4525 - val_accuracy: 0.8735
# Epoch 91/125
#  - 0s - loss: 0.4861 - accuracy: 0.8550 - val_loss: 0.4529 - val_accuracy: 0.8685
# Epoch 92/125
#  - 0s - loss: 0.4818 - accuracy: 0.8590 - val_loss: 0.4554 - val_accuracy: 0.8695
# Epoch 93/125
#  - 0s - loss: 0.4834 - accuracy: 0.8605 - val_loss: 0.4446 - val_accuracy: 0.8770
# Epoch 94/125
#  - 0s - loss: 0.4767 - accuracy: 0.8600 - val_loss: 0.4485 - val_accuracy: 0.8745
# Epoch 95/125
#  - 0s - loss: 0.4886 - accuracy: 0.8551 - val_loss: 0.5191 - val_accuracy: 0.8480
# Epoch 96/125
#  - 0s - loss: 0.4787 - accuracy: 0.8612 - val_loss: 0.4414 - val_accuracy: 0.8730
# Epoch 97/125
#  - 0s - loss: 0.4808 - accuracy: 0.8605 - val_loss: 0.4490 - val_accuracy: 0.8690
# Epoch 98/125
#  - 0s - loss: 0.4707 - accuracy: 0.8566 - val_loss: 0.4389 - val_accuracy: 0.8730
# Epoch 99/125
#  - 0s - loss: 0.4767 - accuracy: 0.8604 - val_loss: 0.4583 - val_accuracy: 0.8675
# Epoch 100/125
#  - 0s - loss: 0.4844 - accuracy: 0.8544 - val_loss: 0.4377 - val_accuracy: 0.8750
# Epoch 101/125
#  - 0s - loss: 0.4840 - accuracy: 0.8543 - val_loss: 0.4519 - val_accuracy: 0.8675
# Epoch 102/125
#  - 0s - loss: 0.4714 - accuracy: 0.8624 - val_loss: 0.4401 - val_accuracy: 0.8730
# Epoch 103/125
#  - 0s - loss: 0.4731 - accuracy: 0.8612 - val_loss: 0.4400 - val_accuracy: 0.8745
# Epoch 104/125
#  - 0s - loss: 0.4911 - accuracy: 0.8529 - val_loss: 0.4406 - val_accuracy: 0.8715
# Epoch 105/125
#  - 0s - loss: 0.4704 - accuracy: 0.8595 - val_loss: 0.4333 - val_accuracy: 0.8775
# Epoch 106/125
#  - 0s - loss: 0.4682 - accuracy: 0.8627 - val_loss: 0.4356 - val_accuracy: 0.8740
# Epoch 107/125
#  - 0s - loss: 0.4667 - accuracy: 0.8637 - val_loss: 0.4481 - val_accuracy: 0.8640
# Epoch 108/125
#  - 0s - loss: 0.4627 - accuracy: 0.8622 - val_loss: 0.4515 - val_accuracy: 0.8695
# Epoch 109/125
#  - 0s - loss: 0.4737 - accuracy: 0.8616 - val_loss: 0.4412 - val_accuracy: 0.8705
# Epoch 110/125
#  - 0s - loss: 0.4622 - accuracy: 0.8627 - val_loss: 0.4400 - val_accuracy: 0.8685
# Epoch 111/125
#  - 0s - loss: 0.4569 - accuracy: 0.8660 - val_loss: 0.4359 - val_accuracy: 0.8725
# Epoch 112/125
#  - 0s - loss: 0.4621 - accuracy: 0.8655 - val_loss: 0.4695 - val_accuracy: 0.8595
# Epoch 113/125
#  - 0s - loss: 0.4723 - accuracy: 0.8593 - val_loss: 0.4573 - val_accuracy: 0.8655
# Epoch 114/125
#  - 0s - loss: 0.4729 - accuracy: 0.8601 - val_loss: 0.4528 - val_accuracy: 0.8685
# Epoch 115/125
#  - 0s - loss: 0.4583 - accuracy: 0.8620 - val_loss: 0.4467 - val_accuracy: 0.8625
# Epoch 116/125
#  - 0s - loss: 0.4659 - accuracy: 0.8637 - val_loss: 0.4353 - val_accuracy: 0.8700
# Epoch 117/125
#  - 0s - loss: 0.4663 - accuracy: 0.8589 - val_loss: 0.4449 - val_accuracy: 0.8680
# Epoch 118/125
#  - 0s - loss: 0.4690 - accuracy: 0.8594 - val_loss: 0.4288 - val_accuracy: 0.8745
# Epoch 119/125
#  - 0s - loss: 0.4576 - accuracy: 0.8639 - val_loss: 0.4626 - val_accuracy: 0.8630
# Epoch 120/125
#  - 0s - loss: 0.4646 - accuracy: 0.8594 - val_loss: 0.4339 - val_accuracy: 0.8730
# Epoch 121/125
#  - 0s - loss: 0.4618 - accuracy: 0.8643 - val_loss: 0.4904 - val_accuracy: 0.8465
# Epoch 122/125
#  - 0s - loss: 0.4630 - accuracy: 0.8600 - val_loss: 0.4384 - val_accuracy: 0.8735
# Epoch 123/125
#  - 0s - loss: 0.4613 - accuracy: 0.8637 - val_loss: 0.4273 - val_accuracy: 0.8725
# Epoch 124/125
#  - 0s - loss: 0.4633 - accuracy: 0.8637 - val_loss: 0.4350 - val_accuracy: 0.8705
# Epoch 125/125
#  - 0s - loss: 0.4594 - accuracy: 0.8619 - val_loss: 0.4346 - val_accuracy: 0.8690
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/125
#  - 1s - loss: 1.2444 - accuracy: 0.3589 - val_loss: 1.1521 - val_accuracy: 0.4510
# Epoch 2/125
#  - 0s - loss: 1.1201 - accuracy: 0.4021 - val_loss: 1.1019 - val_accuracy: 0.4145
# Epoch 3/125
#  - 0s - loss: 1.0978 - accuracy: 0.3862 - val_loss: 1.0927 - val_accuracy: 0.4015
# Epoch 4/125
#  - 0s - loss: 1.0800 - accuracy: 0.4186 - val_loss: 1.0559 - val_accuracy: 0.4520
# Epoch 5/125
#  - 0s - loss: 1.0392 - accuracy: 0.4855 - val_loss: 1.0055 - val_accuracy: 0.5420
# Epoch 6/125
#  - 0s - loss: 1.0042 - accuracy: 0.5347 - val_loss: 0.9781 - val_accuracy: 0.5670
# Epoch 7/125
#  - 0s - loss: 0.9839 - accuracy: 0.5508 - val_loss: 0.9468 - val_accuracy: 0.5800
# Epoch 8/125
#  - 0s - loss: 0.9587 - accuracy: 0.5649 - val_loss: 0.9639 - val_accuracy: 0.5750
# Epoch 9/125
#  - 0s - loss: 0.9474 - accuracy: 0.5826 - val_loss: 0.9034 - val_accuracy: 0.6370
# Epoch 10/125
#  - 0s - loss: 0.9207 - accuracy: 0.6068 - val_loss: 0.8757 - val_accuracy: 0.6645
# Epoch 11/125
#  - 0s - loss: 0.8915 - accuracy: 0.6341 - val_loss: 0.8482 - val_accuracy: 0.6685
# Epoch 12/125
#  - 0s - loss: 0.8595 - accuracy: 0.6630 - val_loss: 0.8025 - val_accuracy: 0.7100
# Epoch 13/125
#  - 0s - loss: 0.8255 - accuracy: 0.6774 - val_loss: 0.7783 - val_accuracy: 0.7190
# Epoch 14/125
#  - 0s - loss: 0.8010 - accuracy: 0.6999 - val_loss: 0.7718 - val_accuracy: 0.7185
# Epoch 15/125
#  - 0s - loss: 0.7783 - accuracy: 0.7040 - val_loss: 0.7346 - val_accuracy: 0.7670
# Epoch 16/125
#  - 0s - loss: 0.7588 - accuracy: 0.7189 - val_loss: 0.7318 - val_accuracy: 0.7655
# Epoch 17/125
#  - 0s - loss: 0.7501 - accuracy: 0.7220 - val_loss: 0.7139 - val_accuracy: 0.7755
# Epoch 18/125
#  - 0s - loss: 0.7379 - accuracy: 0.7305 - val_loss: 0.6933 - val_accuracy: 0.7715
# Epoch 19/125
#  - 0s - loss: 0.7287 - accuracy: 0.7383 - val_loss: 0.6894 - val_accuracy: 0.7665
# Epoch 20/125
#  - 0s - loss: 0.7163 - accuracy: 0.7433 - val_loss: 0.6826 - val_accuracy: 0.7685
# Epoch 21/125
#  - 0s - loss: 0.7109 - accuracy: 0.7470 - val_loss: 0.6632 - val_accuracy: 0.7765
# Epoch 22/125
#  - 0s - loss: 0.7013 - accuracy: 0.7541 - val_loss: 0.6540 - val_accuracy: 0.7835
# Epoch 23/125
#  - 0s - loss: 0.6901 - accuracy: 0.7574 - val_loss: 0.6471 - val_accuracy: 0.7920
# Epoch 24/125
#  - 0s - loss: 0.6826 - accuracy: 0.7591 - val_loss: 0.6399 - val_accuracy: 0.7925
# Epoch 25/125
#  - 0s - loss: 0.6728 - accuracy: 0.7678 - val_loss: 0.6258 - val_accuracy: 0.7970
# Epoch 26/125
#  - 0s - loss: 0.6591 - accuracy: 0.7686 - val_loss: 0.6283 - val_accuracy: 0.7940
# Epoch 27/125
#  - 0s - loss: 0.6555 - accuracy: 0.7716 - val_loss: 0.6218 - val_accuracy: 0.7965
# Epoch 28/125
#  - 0s - loss: 0.6530 - accuracy: 0.7763 - val_loss: 0.6101 - val_accuracy: 0.8040
# Epoch 29/125
#  - 0s - loss: 0.6431 - accuracy: 0.7796 - val_loss: 0.6155 - val_accuracy: 0.7940
# Epoch 30/125
#  - 0s - loss: 0.6446 - accuracy: 0.7790 - val_loss: 0.5974 - val_accuracy: 0.8070
# Epoch 31/125
#  - 0s - loss: 0.6357 - accuracy: 0.7786 - val_loss: 0.5932 - val_accuracy: 0.8115
# Epoch 32/125
#  - 0s - loss: 0.6368 - accuracy: 0.7819 - val_loss: 0.5838 - val_accuracy: 0.8185
# Epoch 33/125
#  - 0s - loss: 0.6201 - accuracy: 0.7920 - val_loss: 0.5926 - val_accuracy: 0.8055
# Epoch 34/125
#  - 0s - loss: 0.6212 - accuracy: 0.7865 - val_loss: 0.5876 - val_accuracy: 0.8135
# Epoch 35/125
#  - 0s - loss: 0.6192 - accuracy: 0.7920 - val_loss: 0.5701 - val_accuracy: 0.8160
# Epoch 36/125
#  - 0s - loss: 0.6145 - accuracy: 0.7951 - val_loss: 0.5612 - val_accuracy: 0.8270
# Epoch 37/125
#  - 0s - loss: 0.6086 - accuracy: 0.7959 - val_loss: 0.5646 - val_accuracy: 0.8245
# Epoch 38/125
#  - 0s - loss: 0.5999 - accuracy: 0.8029 - val_loss: 0.5640 - val_accuracy: 0.8260
# Epoch 39/125
#  - 0s - loss: 0.5878 - accuracy: 0.8023 - val_loss: 0.5617 - val_accuracy: 0.8150
# Epoch 40/125
#  - 0s - loss: 0.5906 - accuracy: 0.8040 - val_loss: 0.5559 - val_accuracy: 0.8260
# Epoch 41/125
#  - 0s - loss: 0.5812 - accuracy: 0.8085 - val_loss: 0.5430 - val_accuracy: 0.8355
# Epoch 42/125
#  - 0s - loss: 0.5830 - accuracy: 0.8061 - val_loss: 0.5401 - val_accuracy: 0.8270
# Epoch 43/125
#  - 0s - loss: 0.5823 - accuracy: 0.8066 - val_loss: 0.5407 - val_accuracy: 0.8230
# Epoch 44/125
#  - 0s - loss: 0.5699 - accuracy: 0.8125 - val_loss: 0.5524 - val_accuracy: 0.8270
# Epoch 45/125
#  - 0s - loss: 0.5657 - accuracy: 0.8108 - val_loss: 0.5301 - val_accuracy: 0.8375
# Epoch 46/125
#  - 0s - loss: 0.5730 - accuracy: 0.8127 - val_loss: 0.5355 - val_accuracy: 0.8310
# Epoch 47/125
#  - 0s - loss: 0.5632 - accuracy: 0.8174 - val_loss: 0.5351 - val_accuracy: 0.8260
# Epoch 48/125
#  - 0s - loss: 0.5663 - accuracy: 0.8127 - val_loss: 0.5267 - val_accuracy: 0.8375
# Epoch 49/125
#  - 0s - loss: 0.5623 - accuracy: 0.8134 - val_loss: 0.5530 - val_accuracy: 0.8175
# Epoch 50/125
#  - 0s - loss: 0.5602 - accuracy: 0.8194 - val_loss: 0.5255 - val_accuracy: 0.8325
# Epoch 51/125
#  - 0s - loss: 0.5511 - accuracy: 0.8183 - val_loss: 0.5226 - val_accuracy: 0.8385
# Epoch 52/125
#  - 0s - loss: 0.5549 - accuracy: 0.8175 - val_loss: 0.5163 - val_accuracy: 0.8400
# Epoch 53/125
#  - 0s - loss: 0.5463 - accuracy: 0.8181 - val_loss: 0.5505 - val_accuracy: 0.8175
# Epoch 54/125
#  - 0s - loss: 0.5519 - accuracy: 0.8189 - val_loss: 0.5112 - val_accuracy: 0.8395
# Epoch 55/125
#  - 0s - loss: 0.5467 - accuracy: 0.8211 - val_loss: 0.5275 - val_accuracy: 0.8305
# Epoch 56/125
#  - 0s - loss: 0.5503 - accuracy: 0.8171 - val_loss: 0.5166 - val_accuracy: 0.8430
# Epoch 57/125
#  - 0s - loss: 0.5392 - accuracy: 0.8245 - val_loss: 0.5138 - val_accuracy: 0.8350
# Epoch 58/125
#  - 0s - loss: 0.5413 - accuracy: 0.8236 - val_loss: 0.5125 - val_accuracy: 0.8365
# Epoch 59/125
#  - 0s - loss: 0.5394 - accuracy: 0.8227 - val_loss: 0.5126 - val_accuracy: 0.8390
# Epoch 60/125
#  - 0s - loss: 0.5466 - accuracy: 0.8190 - val_loss: 0.5054 - val_accuracy: 0.8390
# Epoch 61/125
#  - 0s - loss: 0.5472 - accuracy: 0.8173 - val_loss: 0.5164 - val_accuracy: 0.8305
# Epoch 62/125
#  - 0s - loss: 0.5369 - accuracy: 0.8246 - val_loss: 0.5011 - val_accuracy: 0.8385
# Epoch 63/125
#  - 0s - loss: 0.5399 - accuracy: 0.8210 - val_loss: 0.5035 - val_accuracy: 0.8365
# Epoch 64/125
#  - 0s - loss: 0.5292 - accuracy: 0.8260 - val_loss: 0.5054 - val_accuracy: 0.8375
# Epoch 65/125
#  - 0s - loss: 0.5361 - accuracy: 0.8226 - val_loss: 0.5148 - val_accuracy: 0.8335
# Epoch 66/125
#  - 0s - loss: 0.5326 - accuracy: 0.8213 - val_loss: 0.5291 - val_accuracy: 0.8230
# Epoch 67/125
#  - 0s - loss: 0.5334 - accuracy: 0.8219 - val_loss: 0.5039 - val_accuracy: 0.8370
# Epoch 68/125
#  - 0s - loss: 0.5323 - accuracy: 0.8205 - val_loss: 0.5079 - val_accuracy: 0.8355
# Epoch 69/125
#  - 0s - loss: 0.5318 - accuracy: 0.8248 - val_loss: 0.5017 - val_accuracy: 0.8420
# Epoch 70/125
#  - 0s - loss: 0.5228 - accuracy: 0.8296 - val_loss: 0.5422 - val_accuracy: 0.8220
# Epoch 71/125
#  - 0s - loss: 0.5236 - accuracy: 0.8313 - val_loss: 0.4942 - val_accuracy: 0.8400
# Epoch 72/125
#  - 0s - loss: 0.5262 - accuracy: 0.8261 - val_loss: 0.4996 - val_accuracy: 0.8390
# Epoch 73/125
#  - 0s - loss: 0.5227 - accuracy: 0.8284 - val_loss: 0.4883 - val_accuracy: 0.8425
# Epoch 74/125
#  - 0s - loss: 0.5169 - accuracy: 0.8291 - val_loss: 0.4918 - val_accuracy: 0.8425
# Epoch 75/125
#  - 0s - loss: 0.5195 - accuracy: 0.8298 - val_loss: 0.4874 - val_accuracy: 0.8410
# Epoch 76/125
#  - 0s - loss: 0.5198 - accuracy: 0.8285 - val_loss: 0.4929 - val_accuracy: 0.8375
# Epoch 77/125
#  - 0s - loss: 0.5190 - accuracy: 0.8278 - val_loss: 0.4941 - val_accuracy: 0.8420
# Epoch 78/125
#  - 0s - loss: 0.5148 - accuracy: 0.8288 - val_loss: 0.4884 - val_accuracy: 0.8430
# Epoch 79/125
#  - 0s - loss: 0.5190 - accuracy: 0.8280 - val_loss: 0.4870 - val_accuracy: 0.8435
# Epoch 80/125
#  - 0s - loss: 0.5058 - accuracy: 0.8314 - val_loss: 0.4844 - val_accuracy: 0.8470
# Epoch 81/125
#  - 0s - loss: 0.5170 - accuracy: 0.8253 - val_loss: 0.4919 - val_accuracy: 0.8390
# Epoch 82/125
#  - 0s - loss: 0.5090 - accuracy: 0.8290 - val_loss: 0.4989 - val_accuracy: 0.8400
# Epoch 83/125
#  - 0s - loss: 0.5149 - accuracy: 0.8330 - val_loss: 0.4844 - val_accuracy: 0.8460
# Epoch 84/125
#  - 0s - loss: 0.5139 - accuracy: 0.8263 - val_loss: 0.4788 - val_accuracy: 0.8470
# Epoch 85/125
#  - 0s - loss: 0.5136 - accuracy: 0.8280 - val_loss: 0.4775 - val_accuracy: 0.8490
# Epoch 86/125
#  - 0s - loss: 0.5046 - accuracy: 0.8314 - val_loss: 0.4928 - val_accuracy: 0.8400
# Epoch 87/125
#  - 0s - loss: 0.5093 - accuracy: 0.8334 - val_loss: 0.4769 - val_accuracy: 0.8450
# Epoch 88/125
#  - 0s - loss: 0.5062 - accuracy: 0.8299 - val_loss: 0.4840 - val_accuracy: 0.8435
# Epoch 89/125
#  - 0s - loss: 0.5034 - accuracy: 0.8310 - val_loss: 0.4959 - val_accuracy: 0.8370
# Epoch 90/125
#  - 0s - loss: 0.5103 - accuracy: 0.8319 - val_loss: 0.4717 - val_accuracy: 0.8530
# Epoch 91/125
#  - 0s - loss: 0.5050 - accuracy: 0.8299 - val_loss: 0.4847 - val_accuracy: 0.8430
# Epoch 92/125
#  - 0s - loss: 0.5022 - accuracy: 0.8321 - val_loss: 0.4762 - val_accuracy: 0.8465
# Epoch 93/125
#  - 0s - loss: 0.5073 - accuracy: 0.8291 - val_loss: 0.4770 - val_accuracy: 0.8430
# Epoch 94/125
#  - 0s - loss: 0.4959 - accuracy: 0.8330 - val_loss: 0.4733 - val_accuracy: 0.8475
# Epoch 95/125
#  - 0s - loss: 0.5031 - accuracy: 0.8315 - val_loss: 0.5344 - val_accuracy: 0.8135
# Epoch 96/125
#  - 0s - loss: 0.5036 - accuracy: 0.8330 - val_loss: 0.4801 - val_accuracy: 0.8500
# Epoch 97/125
#  - 0s - loss: 0.4892 - accuracy: 0.8376 - val_loss: 0.5168 - val_accuracy: 0.8220
# Epoch 98/125
#  - 0s - loss: 0.4984 - accuracy: 0.8349 - val_loss: 0.4947 - val_accuracy: 0.8335
# Epoch 99/125
#  - 0s - loss: 0.5064 - accuracy: 0.8326 - val_loss: 0.4922 - val_accuracy: 0.8395
# Epoch 100/125
#  - 0s - loss: 0.5019 - accuracy: 0.8322 - val_loss: 0.4846 - val_accuracy: 0.8405
# Epoch 101/125
#  - 0s - loss: 0.4904 - accuracy: 0.8393 - val_loss: 0.4669 - val_accuracy: 0.8445
# Epoch 102/125
#  - 0s - loss: 0.4957 - accuracy: 0.8320 - val_loss: 0.4701 - val_accuracy: 0.8490
# Epoch 103/125
#  - 0s - loss: 0.4990 - accuracy: 0.8328 - val_loss: 0.4783 - val_accuracy: 0.8420
# Epoch 104/125
#  - 0s - loss: 0.4885 - accuracy: 0.8369 - val_loss: 0.4675 - val_accuracy: 0.8505
# Epoch 105/125
#  - 0s - loss: 0.4933 - accuracy: 0.8370 - val_loss: 0.4745 - val_accuracy: 0.8490
# Epoch 106/125
#  - 0s - loss: 0.4877 - accuracy: 0.8370 - val_loss: 0.4640 - val_accuracy: 0.8500
# Epoch 107/125
#  - 0s - loss: 0.4969 - accuracy: 0.8386 - val_loss: 0.4716 - val_accuracy: 0.8455
# Epoch 108/125
#  - 0s - loss: 0.4903 - accuracy: 0.8372 - val_loss: 0.4678 - val_accuracy: 0.8435
# Epoch 109/125
#  - 0s - loss: 0.4905 - accuracy: 0.8372 - val_loss: 0.4718 - val_accuracy: 0.8475
# Epoch 110/125
#  - 0s - loss: 0.4913 - accuracy: 0.8357 - val_loss: 0.4698 - val_accuracy: 0.8490
# Epoch 111/125
#  - 0s - loss: 0.4912 - accuracy: 0.8326 - val_loss: 0.4807 - val_accuracy: 0.8400
# Epoch 112/125
#  - 0s - loss: 0.4894 - accuracy: 0.8351 - val_loss: 0.4682 - val_accuracy: 0.8550
# Epoch 113/125
#  - 0s - loss: 0.4847 - accuracy: 0.8378 - val_loss: 0.4695 - val_accuracy: 0.8465
# Epoch 114/125
#  - 1s - loss: 0.4883 - accuracy: 0.8385 - val_loss: 0.4745 - val_accuracy: 0.8445
# Epoch 115/125
#  - 1s - loss: 0.4811 - accuracy: 0.8416 - val_loss: 0.4835 - val_accuracy: 0.8425
# Epoch 116/125
#  - 1s - loss: 0.4827 - accuracy: 0.8395 - val_loss: 0.4871 - val_accuracy: 0.8475
# Epoch 117/125
#  - 1s - loss: 0.4800 - accuracy: 0.8396 - val_loss: 0.4739 - val_accuracy: 0.8430
# Epoch 118/125
#  - 1s - loss: 0.4791 - accuracy: 0.8399 - val_loss: 0.4571 - val_accuracy: 0.8530
# Epoch 119/125
#  - 1s - loss: 0.4760 - accuracy: 0.8425 - val_loss: 0.4572 - val_accuracy: 0.8465
# Epoch 120/125
#  - 1s - loss: 0.4818 - accuracy: 0.8403 - val_loss: 0.4576 - val_accuracy: 0.8540
# Epoch 121/125
#  - 0s - loss: 0.4821 - accuracy: 0.8397 - val_loss: 0.4649 - val_accuracy: 0.8525
# Epoch 122/125
#  - 1s - loss: 0.4735 - accuracy: 0.8421 - val_loss: 0.4849 - val_accuracy: 0.8360
# Epoch 123/125
#  - 1s - loss: 0.4728 - accuracy: 0.8428 - val_loss: 0.4616 - val_accuracy: 0.8545
# Epoch 124/125
#  - 1s - loss: 0.4809 - accuracy: 0.8415 - val_loss: 0.4575 - val_accuracy: 0.8525
# Epoch 125/125
#  - 1s - loss: 0.4815 - accuracy: 0.8375 - val_loss: 0.4663 - val_accuracy: 0.8485

# %%
# Grafical comparison

fits = [fit2,fit4,fit6]

plt.close()

# Accuracy
plt.figure(figsize=(10,8))
for fit, test in zip(fits,tests_plot[1::2]):
    
    plt.plot(fit.history['accuracy'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_accuracy'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('accuracy', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='lower right', fontsize=fontsize)    
plt.show()

# Loss
plt.figure(figsize=(10,8))
for fit, test in zip(fits,tests_plot[1::2]):
    
    plt.plot(fit.history['loss'], '--',
            label = test + ' - training data')
    
    plt.plot(fit.history['val_loss'],
            label = test + ' - validation data') 

fontsize = 14
plt.ylabel('loss', fontsize=fontsize)
plt.xlabel('Epochs', fontsize=fontsize)
plt.legend(loc='upper right', fontsize=fontsize)    
plt.show()

# %% [markdown]
# ## 2: Confusion Matrix
#
# As it can be seen from the [relative documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html), the `sklearn.metrics.confusion_matrix` function evaluates classification accuracy by computing the confusion matrix with each row corresponding to the true class, and each column corresponding to the predected one. Notice that [Wikipedia](https://en.wikipedia.org/wiki/Confusion_matrix) and other references may use different convention for axes.
#
# By definition, entry $C_{ij}$ in a confusion matrix $C$ is the number of observations actually in group $i$, but predicted to be in group $j$. Therefore, the diagonal elements represent the number of points for which the predicted label is equal to the true label, while off-diagonal elements are those that are mislabeled by the classifier. The higher the diagonal values of the confusion matrix the better, indicating many correct predictions.
#
# We compute the confusion matrix for the model2, which was the one with the best performance.

# %%
from sklearn.metrics import confusion_matrix

# Uncomment to have a look at the test (val) data one more time:
#print('x, of shape {}: \n'.format(x_val.shape), x_val, '\n')
#print('y, of shape {}: \n'.format(y.shape), y_val, '\n')

y_pred = model2.predict(x_val, batch_size = batch_size)
print('The predicted values are:\n', y_pred)
# Out:
# The predicted values are:
#  [[1.3427341e-03 8.4800425e-04 9.9780923e-01]
#  [4.3608305e-01 2.0940758e-01 3.5450935e-01]
#  [3.2594532e-02 9.6086138e-01 6.5440899e-03]
#  ...
#  [3.9987240e-02 9.5724404e-01 2.7687137e-03]
#  [2.9189927e-03 4.7532740e-04 9.9660563e-01]
#  [8.4352618e-01 1.2897791e-01 2.7495872e-02]]

# %% [markdown]
# In order to compute the confusion matrix, we feed to the confusion_matrix function the index of the maximum value for each row, both for the true labels and for the predicted ones. That index corresponds, moreover, to the wanted category (0 = no signal, 1 = positive signal, 2 = negative signal)

# %%
conf_mat = confusion_matrix(y_val.argmax(axis=1), y_pred.argmax(axis=1))
print(conf_mat)
# Out:
# [[564  60  43]
#  [ 30 605  31]
#  [ 33  43 591]]

# %% [markdown]
# Let's do a rapid check: we compute the accuracy of the model as given by the confusion matrix, and visually compare it to the one plotted previously.

# %%
# Sum the element on the diagonal
sum_diag = np.sum(np.diag(conf_mat)) 
# Sum the offdiagonal terms
sum_offd = np.sum(np.extract(1-np.eye(3), conf_mat))

total_n = sum_diag + sum_offd
# Check if it equals the length of y_val (as it should be):
# total_n == len(y_val)

# Computing and printing the accuracy
print('The percentage of corrected categorized data is {} %'.format(100*sum_diag/total_n) )
# Out:
# The percentage of corrected categorized data is 88.0 %

# %% [markdown]
# The result is, therefore, qualitatively consistent.
#
# Let's plot the confusion matrix:

# %%
import seaborn as sns
import pandas as pd

# Feed the confusion matrix into a pandas dataframe, to ease the labeling process in the plot
df_cm = pd.DataFrame(conf_mat, columns = ['Absent', 'Positive', 'Negative'],
                    index = ['Absent', 'Positive', 'Negative'])

plt.figure(figsize=(10,8))
sns.set(font_scale=1.4) # for label size
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap="coolwarm",
           linewidths=.5)
plt.title("Confusion matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
